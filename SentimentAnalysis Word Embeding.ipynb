# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Reviews = pd.read_csv('Reviews.csv',sep = '\t')

# %%
Reviews.head()
# Out:
#    Unnamed: 0        asin                                       product_name  \
# 0           0  B0009PG35M    ASICS&#174; Men's GEL-Nimbus&#174; VII: Apparel
# 1           1  B0009OTGE8  Bill Blass Men's Dress Shirt with Fashion Poin...
# 2           2  B0002UMZ3S          Woodland Digital Camo 4 Pocket BDU Shirt
# 3           3  B0000720HO  The Original Majamas Sleepy Dress (maternity):...
# 4           4  B000GTSHLE                Lily-Padz - Breast-Feeding: Apparel
#
#   helpful  rating                                    title  \
# 0  5 of 5     5.0    Never buying Nike Running Shoes again
# 1     NaN     5.0                        Bill Blass shirts
# 2  0 of 1     4.0          Woodland & Desert Digital BDU's
# 3  5 of 6     4.0         Decent support for large breasts
# 4  3 of 3     5.0  A must have for every breastfeeding mom
#
#                  date                          reviewer reviewer_location  \
# 0      March 17, 2006                            Shanik               NaN
# 1       March 2, 2006                Richard H. Pontone       Brooklyn,NY
# 2  September 30, 2006  Charles L. Pearlman "Desert Fox"  Palm Springs, CA
# 3       June 29, 2006                          L. Olson           Florida
# 4   February 20, 2007                   Jennifer Suarez                NY
#
#                                          review_text Class
# 0  Seriously, went into the store to find new run...   pos
# 1  The shirts are what I had asked for.  They are...   pos
# 2  See my review for the Desert Digital.  I own b...   pos
# 3  Finding sleepwear that has enough support for ...   pos
# 4  This is a product that every breastfeeding mot...   pos

# %%
ReviewsText =  Reviews.loc[:,'review_text':'Class']

# %%
ReviewsText
# Out:
#                                              review_text Class
# 0      Seriously, went into the store to find new run...   pos
# 1      The shirts are what I had asked for.  They are...   pos
# 2      See my review for the Desert Digital.  I own b...   pos
# 3      Finding sleepwear that has enough support for ...   pos
# 4      This is a product that every breastfeeding mot...   pos
# 5      i was very satisfied with my purchase of these...   pos
# 6      These SOX are the BEST my husband has ever use...   pos
# 7      The New Balance Men's M587 Running Shoe has be...   pos
# 8      When I bought these shoes I didn't know they w...   pos
# 9      quick shipping and a great product, I am looki...   pos
# 10     Very pleased with all aspects of this transact...   pos
# 11     it was easy to order and very affordable and t...   pos
# 12     The Nine West Botamy boots are comfortable and...   pos
# 13          Swimsuit very cute - size as stated (16 = 20   pos
# 14     My twin sister bought these for me, and initia...   pos
# 15     I love this jacket.   It is lightweight but st...   pos
# 16     Plugged into Ipod and guess what! Audio and vi...   pos
# 17     Not very pretty but the comfort makes up for t...   pos
# 18     They look nice and feel AMAZING.  I bought my ...   pos
# 19     I, like many many others, ordered the 4811 and...   pos
# 20     I bought a pair for my wife and she told me ho...   pos
# 21     This is a great idea that is not apriciated un...   pos
# 22     Once my best friend described my bra size as "...   pos
# 23     This is my husband's favorite shirt because it...   pos
# 24     The product arrived in a reasonable time frame...   pos
# 25     Just got them in the mail today. As other kenn...   pos
# 26     These shirts are hard to find during certain s...   pos
# 27     As the weather has cooled for fall and winter,...   pos
# 28     This is a great item to have if you are loosin...   pos
# 29     I was very happy with my last order. It was ea...   pos
# ...                                                  ...   ...
# 38518  i had never known that there was a movie made ...   neg
# 38519  When Danny Devito's plays Larry Garfield he is...   neg
# 38520  I have bought 2 seasons of Survivor on unbox a...   neg
# 38521  Jet Li as a contrac killer? Come on! The reaso...   neg
# 38522  So this movie is made of 2 stories.  The first...   neg
# 38523  Watching this movie is about as much fun as ha...   neg
# 38524  This item is supposedly titled "UFOs: The Firs...   neg
# 38525  I have loved Riverdance since the first time I...   neg
# 38526  I wish that Amazon can get it right, that when...   neg
# 38527  This movie is great if you want to go to sleep...   neg
# 38528  After seeing some of the other Amazon reviews ...   neg
# 38529  It really sucks, tried to download but it's no...   neg
# 38530  I'm a fan of NCIS, but living in australia mea...   neg
# 38531  I don't know what's up with all of these 4-5 s...   neg
# 38532  I brought this movie a couple of days ago and ...   neg
# 38533  This is certainly the WORST movie that Elvis h...   neg
# 38534  Dragonheart did not need a sequel. The story w...   neg
# 38535  I wasn't expecting Disney, but I was less than...   neg
# 38536  This is one of the worst movies ever! It seems...   neg
# 38537  This is a poor excuse of a movie. The actors a...   neg
# 38538  We have a lawman who for no explained reason s...   neg
# 38539  Jeremy Brett was by this time indeed &quot;the...   neg
# 38540  This is not a good Tornado disaster movie by a...   neg
# 38541  Michael Moriarity is my hero! He is just one o...   neg
# 38542  I have bought 2 seasons of Survivor on unbox a...   neg
# 38543  Will not play once video was downloaded. I get...   neg
# 38544  this is another story that I don't know if I l...   neg
# 38545  I originally read the novel (of which I assume...   neg
# 38546  I've been a Timothy Dalton fan ever since I sa...   neg
# 38547  It really sucks, tried to download but it's no...   neg
#
# [38548 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.tokenize import RegexpTokenizer


#nltk.download()
#nltk.download('punkt')
def tokenize_words_Sents(Sent):
    return word_tokenize(Sent),sent_tokenize(Sent)
def tokenize_words(Sent):
    return word_tokenize(Sent)   
def RegExpTokenizer(Sent):
    tokenizer = RegexpTokenizer(r'\w+')
    return tokenizer.tokenize(Sent)

Words,Sents = tokenize_words_Sents(ReviewsText.review_text[1])
print("Words ",Words)
print("Sents ",Sents)
print(RegExpTokenizer(ReviewsText.review_text[1]))
# Out:
# Words  ['The', 'shirts', 'are', 'what', 'I', 'had', 'asked', 'for', '.', 'They', 'are', 'sturdy', 'and', 'well', 'made', '.', 'I', 'would', 'buy', 'more', 'if', 'I', 'needed', 'more', '.', 'Well', 'worth', 'the', 'money', 'spen']
# Sents  ['The shirts are what I had asked for.', 'They are sturdy and well made.', 'I would buy more if I needed more.', 'Well worth the money spen']
# ['The', 'shirts', 'are', 'what', 'I', 'had', 'asked', 'for', 'They', 'are', 'sturdy', 'and', 'well', 'made', 'I', 'would', 'buy', 'more', 'if', 'I', 'needed', 'more', 'Well', 'worth', 'the', 'money', 'spen']

# %%
from nltk.corpus import stopwords
#nltk.download('stopwords')
def Eliminate_Stop_Words(Sent):
    stop_words = set(stopwords.words("english"))
    filtered_words = []
    for w in Sent:
        if w not in stop_words:
            filtered_words.append(w)
    return stop_words,filtered_words

def Eliminate_Stop_Word(Sent):
    stop_words = set(stopwords.words("english"))
    filtered_words = []
    for w in Sent:
        if w not in stop_words:
            filtered_words.append(w)
    return filtered_words

stop_words,filtered_words = Eliminate_Stop_Words(Words)
print(stop_words)
print("------------------Words ------------------------")
print(Words)
print("------------------Words filltred---------------------")
print(filtered_words)
# Out:
# {'further', 'does', 'more', 'haven', 'our', 'all', "you've", 'am', 'during', "couldn't", "doesn't", "won't", 'yourself', 'shan', 'her', 'ourselves', 'in', 'but', 'their', 'and', 'is', 'by', "shan't", "haven't", "weren't", 'than', 'don', "needn't", 'myself', 'such', 'not', 'when', 'it', 'once', "you'd", 'until', 'after', 'has', 'will', "that'll", 'having', 'whom', 'of', 'why', 'some', "wasn't", 'the', 'any', 'didn', 'there', 'so', "shouldn't", 'very', "hadn't", 'i', "you'll", 't', 'you', 'was', 'here', 'she', 'no', 'hers', 'because', 've', 'if', 'out', 'have', 'mightn', 'who', 'now', 'did', 'against', 'that', 'only', 'my', 'be', 'at', 'again', 'same', "should've", 'into', 'just', 'been', "you're", 'are', 'd', 'me', 'needn', 'being', 'shouldn', 'through', 'doesn', 'your', "it's", 'from', "aren't", 'themselves', "didn't", 'should', 'while', 'won', 'we', 'as', 'most', 're', "don't", 'on', 'yours', 'both', 'up', 'y', 'what', 'with', 'yourselves', 'ours', 'other', 'or', 'above', 'before', 'ain', 'aren', 'do', 'each', 'couldn', 'hasn', 'isn', 'had', 'off', 'then', "mustn't", "mightn't", 'this', 'o', 'were', 'doing', 'its', 'a', 'them', 'they', 's', 'hadn', "she's", 'below', "wouldn't", 'those', 'over', 'too', 'nor', 'weren', 'll', 'wasn', 'mustn', 'between', 'which', "hasn't", 'these', 'few', 'wouldn', 'his', 'where', 'can', 'to', 'himself', 'under', 'ma', 'herself', 'him', 'for', 'own', 'how', 'theirs', "isn't", 'he', 'itself', 'm', 'down', 'an', 'about'}
# ------------------Words ------------------------
# ['The', 'shirts', 'are', 'what', 'I', 'had', 'asked', 'for', '.', 'They', 'are', 'sturdy', 'and', 'well', 'made', '.', 'I', 'would', 'buy', 'more', 'if', 'I', 'needed', 'more', '.', 'Well', 'worth', 'the', 'money', 'spen']
# ------------------Words filltred---------------------
# ['The', 'shirts', 'I', 'asked', '.', 'They', 'sturdy', 'well', 'made', '.', 'I', 'would', 'buy', 'I', 'needed', '.', 'Well', 'worth', 'money', 'spen']

# %%
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
def Lemmatizing_Words(Words):
    Lm = WordNetLemmatizer()
    Lemmatized_Words = []
    for m in Words:
        Lemmatized_Words.append(Lm.lemmatize(m))
    return Lemmatized_Words

# %%
Texts = list(ReviewsText['review_text'])
Texts
# Out:
# ["Seriously, went into the store to find new running shoes, possibly the air 360.  Was wearing shoxs in the store.  Threw them away immediately.  These are the best shoes I've worn in a long while.  I'm one of those ppl that like to take off my shoes as soon as I get home.  I forgot that these were on, they were that comfortable.  I'm a heavy, parttime runner.  Nothing over 5K as I am just starting again.  They support my weight extremely well",
#  'The shirts are what I had asked for.  They are sturdy and well made.  I would buy more if I needed more.  Well worth the money spen',
#  'I made a bone head move and just bought one. It cost as much to send it as it did for one shirt. These people have areally good t-shirts. Not thin, and they are stiched well',
#  'Your company was a pleasure to work with- thanks!  I will enjoy wearing the swimsuit that I ordered',
#  'Everyone loved me in these glasses for our "Old Fashioned Banquet"!  They completed my outfit, great price and a speedy delivery - which I really needed',
#  'Good construction and material for the price.  Size seems a bit different in L vs. R unless I am more asymmetrical now than I noticed before?  Nice sheepskin material.  I am hoping this lasts longer than the previous moc I purchased by Acorn',
#  'Good color visibility; nicely structured with warmth applicable to the unspeakable and inhuman frigidites of the amerikan North.',
#  'Very warm and comfortable for the price.  For any price, really.  Nice, looks good, feels comfy, keeps warm and cuts wind without reducing hearing in the least',
#  'This is just the thing to put away for a Christmas gift.  Nice product in a nice box, tied with a bow.',
#  'speedy delivery  product  as  stated   would buy from them agai',
#  "Finally!  I've been looking for a good bust enhancer for several years. These enhancers are well-shaped and incredibly comfortable.  When ordering, go ahead and get the B",
#  'This is a great hard-side suitcase for the price.  It is basic and simple, but seems quite durable and functional.  I use it for taking my folding bicycle with me when travelling, and it is big enough that the bike fits in, but small enough that the airlines don\'t charge a premium for checking it.  It rolls very well on the built-in wheels, and unlike it\'s smaller cousin the Oyster, this rolls with much more stability due to the wide stance. The only reasons I didn\'t give it 5 stars are: 1) Sometimes the wide rolling stance is a hassle, e.g. going through narrow gates on a subway or similar, and 2) the built-in locks are not "TSA" locks, so in other words, they are useless for air flight.',
#  "These shoes are so comfortable and cute! I've gotten a lot of compliments on them, and I like their old-school Pony look",
#  'I use these socks for running and they are very well cushioned and comfortable. they also withstand frequent laundry without loosing quality. ',
#  "The beading on the bag is fantastic, and its very cute.  The color is even more exquisite in person.  It's just big enough to hold ID, a little money, and a lipstick, perfect for going out at night",
#  "This is the best of the small front pocket wallets available.  Other front pocket wallets have gimmicky designs that don't work well.  This is designed on the same pattern as a full size wallet, only reduced to 4x3 inches.  Holds three cards, bills, and ID as well as having a little room under the ID card for business cards.  Great buy",
#  'These are the best windproof liner gloves out there.  I freaked out thinking they had discontinued them because I thought they were made of Gore Windstopper and couldn\'t find any that said "made with Gore Windstopper" but actually it\'s Polarguard Windbloc.  In any case, when you freak out becuase you think you might not be able to get something again you realize just how much you like that thing. ',
#  "This is a great and comfortable bra, and it works for me. It's a MINIMIZER, and is great for larger sizes. I exercise a lot and it provides great support, even good enough for running on the treadmill. I have a few of these same bras that have lasted several years. I am so impressed with them that I looked up the tag numbers on the bras and found this site to purchase more, and it is half of what I paid in the mall. Now it is all I wear for everyday :)",
#  "Fits, Great quality,great sale price- If your lucky you don't get what you pay for",
#  'Good quality for the great price.  Bought for my 10 year old son and should fit perfect.  Item was on backorder but still received in less than a week',
#  "Munsingwear is definitely the most comfortable, best fitting men's brief I have ever worn",
#  'I love these Crocs!  They are much more comfortable than the original style, and I like the two tone color combo.  I wear them even in the winter',
#  "My husband is a big man and very rough on belts.  Most belts last him a few weeks.  This one has lasted him 3+ years.  The only reason I'm buying him a new one is because he's lost so much weight.  There's still 'lots of miles' left in the belt I'm replacing.  Definitely got our money's worth out of it",
#  ...]

# %%
#GEt words from Review_text m3neha Tokenize 
#RegExpTokenizer to get rid of ponctuation
ListWords =  [RegExpTokenizer(str(m)) for m in Texts]
print(ListWords[1])
#Eliminate Stop_Words
ListWords =  [Eliminate_Stop_Word(m) for m in ListWords]
print(ListWords[1])
#Lemmatizing
ListWords = [Lemmatizing_Words(m) for m in ListWords]
print(ListWords[1])
# Out:
# ['The', 'shirts', 'are', 'what', 'I', 'had', 'asked', 'for', 'They', 'are', 'sturdy', 'and', 'well', 'made', 'I', 'would', 'buy', 'more', 'if', 'I', 'needed', 'more', 'Well', 'worth', 'the', 'money', 'spen']
# ['The', 'shirts', 'I', 'asked', 'They', 'sturdy', 'well', 'made', 'I', 'would', 'buy', 'I', 'needed', 'Well', 'worth', 'money', 'spen']
# ['The', 'shirt', 'I', 'asked', 'They', 'sturdy', 'well', 'made', 'I', 'would', 'buy', 'I', 'needed', 'Well', 'worth', 'money', 'spen']

# %%
def eliminate_irrelevent_Words(ListWords):
    ListWords1 = [] 
    for m in ListWords:
        l = [item.lower() for item in m]
        ListWords1.append(l)
    ListWords = ListWords1
    #print(ListWords)
    #elimnate words
    for m in ListWords:
        for w in m:
            if len(w) <=3:
                m.remove(w)
            if w == 'this':
                m.remove(w)
    return ListWords

# %%
ListWords = eliminate_irrelevent_Words(ListWords)
ListWords
# Out:
# [['seriously',
#   'went',
#   'store',
#   'find',
#   'running',
#   'shoe',
#   'possibly',
#   '360',
#   'wearing',
#   'shoxs',
#   'store',
#   'threw',
#   'away',
#   'immediately',
#   'these',
#   'best',
#   'shoe',
#   'worn',
#   'long',
#   'one',
#   'like',
#   'take',
#   'shoe',
#   'soon',
#   'get',
#   'home',
#   'forgot',
#   'comfortable',
#   'heavy',
#   'parttime',
#   'runner',
#   'nothing',
#   'i',
#   'starting',
#   'they',
#   'support',
#   'weight',
#   'extremely',
#   'well'],
#  ['shirt',
#   'asked',
#   'they',
#   'sturdy',
#   'well',
#   'made',
#   'would',
#   'i',
#   'needed',
#   'well',
#   'worth',
#   'money',
#   'spen'],
#  ['review', 'desert', 'digital', 'woodland', 'desert'],
#  ['finding',
#   'sleepwear',
#   'enough',
#   'support',
#   'lactating',
#   'large',
#   'breasted',
#   'woman',
#   'dress',
#   'pretty',
#   'good',
#   'what',
#   'give',
#   'kind',
#   'coverage',
#   'ok',
#   'people',
#   'seeing',
#   'major',
#   'cleavage',
#   'fine',
#   'wear',
#   'hospital',
#   'see',
#   'woman',
#   'house',
#   'yikes',
#   'think',
#   'arrested'],
#  ['product',
#   'every',
#   'breastfeeding',
#   'mother',
#   'need',
#   'know',
#   'finally',
#   'solution',
#   'leaking',
#   'sleep',
#   'without',
#   'wearing',
#   'using',
#   'lilypadz',
#   'month',
#   'must',
#   'love',
#   'when',
#   'started',
#   'breastfeeding',
#   'daughter',
#   'using',
#   'traditional',
#   'round',
#   'cotton',
#   'put',
#   'inside',
#   'soak',
#   'leak',
#   'hated',
#   'look',
#   'terrible',
#   'snug',
#   'fitting',
#   'shirt',
#   'always',
#   'absorb',
#   'liquid',
#   'shift',
#   'position',
#   'leaving',
#   'protection',
#   'i',
#   'assumed',
#   'necessary',
#   'evil',
#   'breastfeeding',
#   'i',
#   'know',
#   'something',
#   'wonderful',
#   'lilypadz',
#   'existed'],
#  ['satisfied', 'purchase', 'item', 'reasonable', 'price', 'happy', 'item'],
#  ['these',
#   'best',
#   'husband',
#   'ever',
#   'used',
#   'asked',
#   'thrown',
#   'calf',
#   'trash',
#   'construction',
#   'almost',
#   'yr',
#   'never',
#   'happy'],
#  ['new',
#   'balance',
#   'm587',
#   'running',
#   'shoe',
#   'excellent',
#   'running',
#   'shoe',
#   'built',
#   'rollbar',
#   'prevent',
#   'shin',
#   'splint',
#   'shoe',
#   'extremely',
#   'comfortable',
#   'buying',
#   'shoe',
#   'four',
#   'year',
#   'deployment',
#   'iraq',
#   'i',
#   'recommend',
#   'shoe',
#   'runner',
#   '4',
#   'time',
#   'week'],
#  ['when',
#   'bought',
#   'shoe',
#   'know',
#   'would',
#   'look',
#   'pretty',
#   'glad',
#   'bought',
#   'shoe'],
#  ['quick',
#   'shipping',
#   'great',
#   'product',
#   'looking',
#   'forward',
#   'using',
#   'very',
#   'soon'],
#  ['very',
#   'pleased',
#   'aspect',
#   'transaction',
#   'price',
#   'delivery',
#   'quality',
#   'excellent',
#   'recommend',
#   'seller',
#   'highly'],
#  ['easy', 'order', 'affordable', 'quickly', 'want', 'thank'],
#  ['nine',
#   'west',
#   'botamy',
#   'boot',
#   'comfortable',
#   'really',
#   'well',
#   'made',
#   'leather',
#   'soft',
#   'also',
#   'even',
#   'though',
#   'pointed',
#   'boot',
#   'still',
#   'comfortable',
#   'amazon',
#   'great',
#   'price',
#   'boot'],
#  ['swimsuit', 'cute', 'size', 'stated', '20'],
#  ['twin',
#   'sister',
#   'bought',
#   'initially',
#   'thought',
#   'tall',
#   'would',
#   'never',
#   'comfortable'],
#  ['love',
#   'jacket',
#   'lightweight',
#   'still',
#   'warm',
#   'enough',
#   'wear',
#   'coldest',
#   'weather',
#   'also',
#   'long',
#   'enough',
#   'cover',
#   'rear',
#   'very',
#   'good',
#   'rain'],
#  ['plugged',
#   'ipod',
#   'guess',
#   'audio',
#   'video',
#   'came',
#   'a',
#   'little',
#   'spendy'],
#  ['pretty',
#   'comfort',
#   'make',
#   'foot',
#   'used',
#   'wear',
#   'reeboks',
#   'nike',
#   'decided',
#   'crocs',
#   'gone',
#   'back',
#   'like',
#   'walking',
#   'slipper',
#   'wearing',
#   'month',
#   'recently',
#   'tried',
#   'tennis',
#   'shoe',
#   'barely',
#   'made',
#   'by',
#   'night',
#   'foot',
#   'back',
#   'hurting',
#   'didnt',
#   'want',
#   'much',
#   'right',
#   'made',
#   'mind',
#   'never',
#   'back',
#   'tennis',
#   'shoe',
#   'i',
#   'wish',
#   'little',
#   'cheaper',
#   'i',
#   'could',
#   'color',
#   'wardrobe',
#   'wont',
#   'sorry',
#   'stay',
#   'away',
#   'look',
#   'like',
#   'nothing',
#   'like',
#   'original',
#   'crocs',
#   'comfort'],
#  ['they',
#   'look',
#   'nice',
#   'feel',
#   'amazing',
#   'bought',
#   'husband',
#   'soon',
#   'arrived',
#   'asked',
#   'they',
#   'great',
#   'cushion',
#   'flatten',
#   'wash'],
#  ['like',
#   'many',
#   'many',
#   'others',
#   'ordered',
#   '4811',
#   '4911',
#   'read',
#   'article',
#   'ordered',
#   'directly',
#   'herroom',
#   '6'],
#  ['bought',
#   'pair',
#   'wife',
#   'told',
#   'warm',
#   'foot',
#   'wearing',
#   'decided',
#   'pair',
#   'wear',
#   'without',
#   'sock',
#   'warm',
#   'comfortable',
#   'think',
#   'wearing',
#   'sock'],
#  ['great',
#   'idea',
#   'apriciated',
#   'long',
#   'trip',
#   'dirty',
#   'wrinkled',
#   'clothes',
#   'thrown',
#   'this',
#   'keep',
#   'clothes',
#   'seperated',
#   'organized',
#   'easy',
#   'repack',
#   'moving',
#   'place',
#   'place'],
#  ['once',
#   'best',
#   'friend',
#   'described',
#   'size',
#   'beige',
#   'meaning',
#   'shop',
#   'full',
#   'figure',
#   'section',
#   'department',
#   'store',
#   'feel',
#   'like',
#   'accidentally',
#   'walked',
#   'granny',
#   'closet',
#   'most',
#   'beige',
#   'black',
#   'white',
#   'gigantic',
#   'ugly'],
#  ['husband',
#   'favorite',
#   'shirt',
#   'light',
#   'comfortable',
#   'favorite',
#   'shirt',
#   'need',
#   'ironing',
#   'always',
#   'look',
#   'crisp',
#   'neat'],
#  ['product',
#   'arrived',
#   'reasonable',
#   'time',
#   'frame',
#   'ordered',
#   'really',
#   'like'],
#  ['just',
#   'mail',
#   'today',
#   'kenneth',
#   'cole',
#   'reaction',
#   'shoe',
#   'size',
#   'larger',
#   'usually',
#   'i',
#   'ordered',
#   'fit',
#   'right',
#   'these',
#   'boot',
#   'look',
#   'great',
#   'jean',
#   'color',
#   'darker',
#   'one',
#   'shown',
#   'photograph'],
#  ['these',
#   'shirt',
#   'hard',
#   'find',
#   'certain',
#   'season',
#   'happy',
#   'find',
#   'amazon',
#   'quality',
#   'shirt',
#   'lasted',
#   'long',
#   'time',
#   'fit',
#   'perfect',
#   'comfortable'],
#  ['weather',
#   'cooled',
#   'fall',
#   'winter',
#   'needed',
#   'sock',
#   'baby',
#   'initially',
#   'bought',
#   'little',
#   'cotton',
#   'sock',
#   'found',
#   'baby',
#   'store',
#   'department',
#   'store',
#   'hold',
#   'well',
#   'also',
#   'tried',
#   'sock',
#   'grip',
#   'bottom',
#   'thick',
#   'sweated',
#   'children',
#   'place',
#   'sock',
#   'thick',
#   'durable',
#   'also',
#   'slip',
#   'feature',
#   'bottom',
#   'sock',
#   'tried',
#   'hardwood',
#   'floor',
#   'thing',
#   'kept',
#   'baby',
#   'slipping',
#   'floor',
#   'walked',
#   'sock',
#   'strongly',
#   'recommend',
#   'sock',
#   'child'],
#  ['great',
#   'item',
#   'loosing',
#   'weight',
#   'adjust',
#   'belt',
#   'needed',
#   'without',
#   'new'],
#  ['happy',
#   'last',
#   'order',
#   'easy',
#   'order',
#   'take',
#   'long',
#   'product',
#   'grandson',
#   'happy',
#   'little',
#   'christmas',
#   'morning',
#   'thank',
#   'much',
#   'great',
#   'service',
#   'use',
#   'amazon',
#   'tell',
#   'friend'],
#  ['sheet',
#   'described',
#   'worth',
#   'price',
#   'timely',
#   'shippng',
#   'also',
#   'very',
#   'pleased'],
#  ['great',
#   'gown',
#   'price',
#   'comfy',
#   'soft',
#   'even',
#   'small',
#   'support',
#   'busted',
#   'girl',
#   'moreover',
#   'sexy',
#   'hope',
#   'yall',
#   'enjoy'],
#  ['purchased',
#   'recently',
#   'overseas',
#   'trip',
#   'along',
#   'nxt',
#   'roller',
#   'happy',
#   'styling',
#   'excellent',
#   'hold',
#   'expected',
#   'comfortable',
#   'hold',
#   'hand',
#   'sling',
#   'shoulder',
#   'purchased',
#   'black',
#   'version',
#   'victorinox',
#   'lifetime',
#   'guarantee',
#   'wrong',
#   'amazon',
#   'competitive',
#   'price',
#   'though',
#   'store',
#   'cheaper',
#   'felt',
#   'worth',
#   'amazon',
#   'trust'],
#  ['best', 'running', 'look', 'cool', 'comfortable', 'enough', 'wear', 'styl'],
#  ['very',
#   'nice',
#   'sandal',
#   'lookes',
#   'great',
#   'dress',
#   'jean',
#   'enough',
#   'wear',
#   'hour',
#   'time',
#   'high',
#   'enough',
#   'heel',
#   'make',
#   'look',
#   'chic'],
#  ['bought',
#   'boyfriend',
#   'he',
#   'would',
#   'carry',
#   'extra',
#   'clothes',
#   'wallet',
#   'phone',
#   'bundled',
#   'shove',
#   'everything',
#   'locker',
#   'dropping',
#   'everything',
#   'along',
#   'he',
#   'really',
#   'like',
#   'especially',
#   'extra',
#   'front',
#   'pocket',
#   'allows',
#   'seperate',
#   'small',
#   'stuff',
#   'many',
#   'product',
#   'extra',
#   'pocket',
#   'very',
#   'sturdy',
#   'material',
#   'size',
#   'right'],
#  ['love',
#   'shoe',
#   'comfortable',
#   'great',
#   'price',
#   'gold',
#   'really',
#   'happy',
#   'purchase'],
#  ['assure',
#   'anyone',
#   'even',
#   'remotely',
#   'thinking',
#   'buying',
#   'shoe',
#   'it',
#   'they',
#   'beautiful',
#   'high',
#   'extremely',
#   'comfortable',
#   'detail',
#   'beautiful',
#   'person',
#   'website',
#   'favorite',
#   'shoe',
#   'summer'],
#  ['shoe',
#   'wear',
#   'well',
#   'match',
#   'nicely',
#   'jean',
#   'giving',
#   'nice',
#   'fresh',
#   'look',
#   'also',
#   'easy',
#   'foot',
#   'like',
#   'suede',
#   'version',
#   'best',
#   'personally',
#   'winter',
#   'best',
#   'leather'],
#  ['great',
#   'mother',
#   'looking',
#   'nursing',
#   'live',
#   'terrible',
#   'time',
#   'finding',
#   'store',
#   'anywhere',
#   'line',
#   'fabulous',
#   'it',
#   'comfortable',
#   'washed',
#   'nicely',
#   'provides',
#   'great',
#   'support',
#   'second',
#   'child',
#   'wish',
#   'i',
#   'first'],
#  ['love', 'shoe', 'everyone', 'i', 'envy', 'girl', 'work'],
#  ['very',
#   'comfortable',
#   'better',
#   'quality',
#   'good',
#   'rubber',
#   'sole',
#   'lotsa',
#   'inside',
#   'sizing',
#   'appears',
#   'right',
#   'take',
#   'shoe',
#   'fit',
#   'right',
#   'lace',
#   'actually',
#   'tighten',
#   'pull',
#   'back',
#   'heel',
#   'normally',
#   'happens',
#   'shoe',
#   'doubt',
#   'last',
#   'long',
#   'outside',
#   'wear',
#   'slipper',
#   'store',
#   'highly',
#   'recommended'],
#  ['durable',
#   'trail',
#   'looking',
#   'something',
#   'carry',
#   'running',
#   'item',
#   'winter',
#   'season',
#   'durable',
#   'well',
#   'comfortable',
#   'cheap',
#   'i',
#   'worry',
#   'ripping',
#   'strap',
#   'padded',
#   'feel',
#   'really',
#   'secure',
#   'shoulder',
#   'part',
#   'across',
#   'back',
#   'nicely',
#   'padded',
#   'already',
#   'saved',
#   'nasty',
#   'spill',
#   'need',
#   'book',
#   'padding',
#   'keep',
#   'book',
#   'poking',
#   'back',
#   'i',
#   'would',
#   'imagine',
#   'would',
#   'hot',
#   'back',
#   'summer',
#   'though'],
#  ['fifth',
#   'pair',
#   'club',
#   'owned',
#   'second',
#   'black',
#   'believe',
#   'best',
#   'combination',
#   'durability',
#   'comfort',
#   'market',
#   'i',
#   'undoubtedly',
#   'another',
#   'pair',
#   'wear'],
#  ['order',
#   'half',
#   'size',
#   'review',
#   'length',
#   'perfect',
#   'however',
#   'unisex',
#   'width',
#   'wide',
#   'pair',
#   'men',
#   'ultimate',
#   'wide'],
#  ['using',
#   'awhile',
#   'unlike',
#   'sport',
#   'supportive',
#   'lighter',
#   'weight',
#   'material'],
#  ['love',
#   'birkenstock',
#   'shoe',
#   'they',
#   'fill',
#   'great',
#   'registered',
#   'nurse',
#   'foot',
#   'constantly',
#   'these',
#   'shoe',
#   'great',
#   'support',
#   'foot',
#   'need',
#   'they',
#   'really',
#   'comfortable',
#   'definately',
#   'purchasing',
#   'near',
#   'future'],
#  ['nice', 'shirt', 'hard', 'find', 'store', 'worth', 'wait', 'cash'],
#  ['love',
#   'garrick',
#   'sandal',
#   'exactly',
#   'expected',
#   'seen',
#   'store',
#   'delivery',
#   'service',
#   'excellent'],
#  ['purchased',
#   'scarlett',
#   'version',
#   'two',
#   'year',
#   'still',
#   'perfect',
#   'condition',
#   'color',
#   'fade',
#   'wash',
#   'durable',
#   'ever',
#   'owned',
#   'refuse',
#   'absolutely',
#   'cannot',
#   'make',
#   'carry',
#   'purse',
#   'carry',
#   'everyday',
#   'front',
#   'zipper',
#   'pocket',
#   'great',
#   'change',
#   'small',
#   'zipper',
#   'hold',
#   'cell',
#   'host',
#   'small',
#   'item',
#   'always',
#   'seemed',
#   'losing',
#   'large',
#   'pocket',
#   'enough',
#   'several',
#   'medium',
#   'sized',
#   'paperback',
#   'perfect',
#   'everyday',
#   'last',
#   'forever',
#   'backpack',
#   'strap',
#   'comfortable',
#   'never',
#   'broken',
#   'excited',
#   'i',
#   'found',
#   'amazon',
#   'every',
#   'color',
#   'before',
#   'selection',
#   'black',
#   'fabulous',
#   'bag',
#   'love'],
#  ['sharp', 'shoe', 'comfortable', 'well'],
#  ['these',
#   'shoe',
#   'look',
#   'great',
#   'feel',
#   'wonderful',
#   'they',
#   'light',
#   'weight',
#   'comfortable',
#   'great',
#   'product',
#   'great',
#   'price'],
#  ['product',
#   'really',
#   'great',
#   'sansa',
#   'e260',
#   'purchased',
#   'strongly',
#   'recommend',
#   'player',
#   'help',
#   'grip',
#   'bottons',
#   'work',
#   'better',
#   'look',
#   'cool'],
#  ['purchased',
#   'white',
#   'entrance',
#   'wedge',
#   'sandal',
#   'steve',
#   'madden',
#   'amaon',
#   'love',
#   'them',
#   'they',
#   'cute',
#   'everything',
#   'perfect',
#   'shoe',
#   'beach',
#   'night',
#   'people',
#   'compliment',
#   'wear',
#   'dissapointed',
#   'they',
#   'comfortable',
#   'say',
#   'i',
#   'love'],
#  ['these',
#   'pleasing',
#   'what',
#   'say',
#   'besides',
#   'fact',
#   'jean',
#   'great',
#   'look',
#   'great',
#   'attract',
#   'alot',
#   'attention'],
#  ['these',
#   'good',
#   'quality',
#   'slipper',
#   'comfortable',
#   'well',
#   'worth',
#   'price'],
#  ['company',
#   'gave',
#   'good',
#   'service',
#   'they',
#   'called',
#   'personally',
#   'couple',
#   'time',
#   'make',
#   'sure',
#   'everything',
#   'correct',
#   'bit',
#   'diappointed',
#   'bigger',
#   'size',
#   'selection',
#   'color',
#   'large',
#   'okay',
#   'they',
#   'granny',
#   'apple',
#   'red'],
#  ['love',
#   'umbrella',
#   'right',
#   'size',
#   'work',
#   'perfectly',
#   'pretty',
#   'want',
#   'wet'],
#  ['best',
#   'brand',
#   'slipper',
#   'ever',
#   'owned',
#   'cute',
#   'pink',
#   'pair',
#   'slip',
#   'minute',
#   'get',
#   'home',
#   'they',
#   'lasted',
#   'several',
#   'year',
#   'still',
#   'good',
#   'shape'],
#  ['lilyette',
#   'maximum',
#   'support',
#   'well',
#   'made',
#   'wear',
#   'well',
#   'hold',
#   'frequent',
#   'washing',
#   'retains',
#   'support',
#   'feature',
#   'comfortable'],
#  ['these',
#   'boxer',
#   'much',
#   'nicer',
#   'photo',
#   'suggest',
#   'pleasantly',
#   'surprised',
#   'trying',
#   'replace',
#   'pair',
#   'accidentally',
#   'washed',
#   'washing',
#   'machine',
#   'fabric',
#   'turns',
#   'replacement',
#   'twice',
#   'quality',
#   'originally',
#   'purchased',
#   'probably',
#   'purchasing'],
#  ['podría',
#   'extraño',
#   'regalar',
#   'prenda',
#   'ropa',
#   'íntima',
#   'pero',
#   'estos',
#   'boxer',
#   'lo',
#   'máximo',
#   'para',
#   'regalar',
#   'desde',
#   'primo',
#   'hasta',
#   'compañero',
#   'estudios',
#   'claro',
#   'para',
#   'pareja',
#   'incluso',
#   'para',
#   'chicas',
#   'algodón',
#   'suaves',
#   'fresco',
#   'ligeros',
#   'compré',
#   'talla',
#   'auqnue',
#   'para',
#   'caballero',
#   'delgado',
#   'm',
#   'medio',
#   'llenito',
#   'puede',
#   'usar',
#   'comodidad',
#   'para',
#   'gusto',
#   'un',
#   'poco',
#   'largo',
#   'pero',
#   'también',
#   'provee',
#   'comodidad',
#   'usuario',
#   'esto',
#   'más',
#   'prenda',
#   'de',
#   'ropa',
#   'interior',
#   'algo',
#   'provoca',
#   'lucir',
#   'lucir',
#   'estampado',
#   'toda',
#   'una',
#   'celebración',
#   'saluda',
#   'pequeño',
#   'amigo',
#   'este',
#   'boxer',
#   'puedes',
#   'pasearte',
#   'interiores',
#   'tu',
#   'casa',
#   'nadie',
#   'va',
#   'molestar'],
#  ['comfortable',
#   'shoe',
#   'ever',
#   'worn',
#   'high',
#   'really',
#   'support',
#   'ankle',
#   'shoe',
#   'form',
#   'fitting',
#   'one',
#   'big',
#   'bulkly',
#   'tennis',
#   'shoe',
#   'light',
#   'weight',
#   'flexilble',
#   'still',
#   'supportive',
#   'well',
#   'worth'],
#  ['shoe', 'wear', 'dress', 'dress', 'review', 'adjust', 'slasp', 'helpful'],
#  ['these',
#   'trunk',
#   'great',
#   'pouch',
#   'front',
#   'work',
#   'great',
#   'keeping',
#   'everything',
#   'together',
#   'comfortable',
#   'drive',
#   'alot',
#   'best',
#   'underwear',
#   'ever'],
#  ['price',
#   'cannot',
#   'beat',
#   'there',
#   'terribly',
#   'large',
#   'right',
#   'size',
#   'goody',
#   'purchased',
#   'girl',
#   'personalized',
#   'ready',
#   'give'],
#  ['opportunity',
#   'wearing',
#   'husband',
#   'left',
#   'west',
#   'coast',
#   'annual',
#   'visit',
#   'friend',
#   'second',
#   'annual',
#   'lingerie',
#   'party',
#   'hubby',
#   'believe',
#   'wear',
#   'something',
#   'like',
#   'oh',
#   'object',
#   'take',
#   'well',
#   'imagine',
#   'take'],
#  ['fan',
#   'asics',
#   'shoe',
#   'many',
#   'year',
#   'foot',
#   'tend',
#   'overpronate',
#   'terrible',
#   'strain',
#   'knee',
#   'arch',
#   'asics',
#   'duomax',
#   'technology',
#   'allows',
#   'comfortably',
#   'love',
#   'stopped',
#   'many',
#   'year',
#   'strain',
#   'joint',
#   'found',
#   'shoe',
#   'absolutely',
#   'love',
#   'shoe',
#   'helped',
#   'regain',
#   'confidence',
#   'comfort',
#   'enjoy',
#   'running',
#   'type',
#   'shoe',
#   'ever',
#   'one',
#   'bought',
#   'year',
#   'highly',
#   'recommend',
#   'shoe',
#   'especially',
#   'foot',
#   'tend',
#   'overpronate'],
#  ['bought',
#   'daughter',
#   'pink',
#   'camo',
#   'anyway',
#   'quality',
#   'product',
#   'daughter',
#   'love',
#   'what'],
#  ['son',
#   'like',
#   'sleep',
#   'wear',
#   'pant',
#   'winter',
#   'they',
#   'perfect',
#   'washing',
#   'easily',
#   'retaining',
#   'size',
#   'color'],
#  ['love', 'shoe', 'comfortable', 'wear', 'anything'],
#  ['needed',
#   'plastic',
#   'coated',
#   'started',
#   'solid',
#   'started',
#   'super',
#   'stiff',
#   'plastic',
#   'babies',
#   'us',
#   'stiff',
#   'great',
#   'keeping',
#   'clothes',
#   'would',
#   'keep',
#   'high',
#   'chair',
#   'svan',
#   'high',
#   'chair',
#   'best',
#   'pretty',
#   'small',
#   'opening',
#   'torso',
#   'stiff',
#   'constantly',
#   'stuffing',
#   'pain',
#   'also',
#   'cleaning',
#   'got',
#   'back',
#   'fabric',
#   'side',
#   'would',
#   'cold',
#   'wet',
#   'hour',
#   'bumkins',
#   'washed',
#   'thorougly',
#   'soap',
#   'water',
#   'sink',
#   'hung',
#   'they',
#   'totally',
#   'next',
#   'meal',
#   'they',
#   'soft',
#   'daugher',
#   'mind',
#   'wearing',
#   'they',
#   'way',
#   'stay',
#   'nicely',
#   'tucked',
#   'assuming',
#   'daughter',
#   'pull',
#   'look',
#   'goody',
#   'pocket',
#   'bought',
#   'set',
#   'could',
#   'easily',
#   'they',
#   'also',
#   'washed',
#   'washing',
#   'machine',
#   'dryer',
#   'dry',
#   'super',
#   'fast'],
#  ['ordered',
#   'product',
#   'dance',
#   'none',
#   'least',
#   'size',
#   'small',
#   'when',
#   'contacted',
#   'dance',
#   'regarding',
#   'issue',
#   'told',
#   'shoe',
#   'sized',
#   'women',
#   'need',
#   'size',
#   'larger',
#   'street',
#   'shoe',
#   'size',
#   'found',
#   'reference',
#   'detail',
#   'amazon',
#   'website',
#   'dance',
#   'representative',
#   'told',
#   'referenced',
#   'website',
#   'amazon',
#   'make',
#   'fact',
#   'known'],
#  ['impressed',
#   'shirt',
#   'buy',
#   'another',
#   'best',
#   'friend',
#   'birthday',
#   'yet',
#   'expression',
#   'since',
#   'thought',
#   'awesome',
#   'knew',
#   'would',
#   'love',
#   'different',
#   'bowling',
#   'league',
#   'everyone',
#   'else',
#   'kick',
#   'opinion',
#   'good',
#   'team',
#   'together',
#   'order',
#   'cruisinusa',
#   'mind',
#   'gutter',
#   'speak',
#   'these',
#   'shirt',
#   'awesome',
#   'give',
#   'bowlingshirts',
#   '10',
#   'star',
#   'bravo'],
#  ['got',
#   'reminded',
#   'jack',
#   'nicholson',
#   'wore',
#   'flew',
#   'over',
#   'cuckoo',
#   'nest',
#   'happy',
#   'also',
#   'keep',
#   'head',
#   'quite',
#   'warm',
#   'cashmere',
#   'soft',
#   'breathes',
#   'well',
#   'head',
#   'never',
#   'feel'],
#  ['love',
#   'sock',
#   'they',
#   'great',
#   'month',
#   'daughter',
#   'thick',
#   'ankle',
#   'zoom',
#   'around',
#   'kitchen',
#   'floor',
#   'take',
#   'nose',
#   'dive',
#   'thing'],
#  ['shirt',
#   'cute',
#   'want',
#   'order',
#   'larger',
#   'size',
#   'child',
#   'normally',
#   'would',
#   'wear',
#   'child',
#   'normally',
#   'wear',
#   'month',
#   'ordered',
#   'size',
#   'much',
#   'tighter',
#   'shorter'],
#  ['these',
#   'shoe',
#   'make',
#   'foot',
#   'look',
#   'tiny',
#   'cute',
#   'wore',
#   'jean',
#   'wear',
#   'pencil',
#   'skirt',
#   'next',
#   'week',
#   'turns',
#   'jessica',
#   'make',
#   'pretty',
#   'good',
#   'shoe',
#   'cute'],
#  ['followed',
#   'advice',
#   'reviewer',
#   'ordered',
#   'half',
#   'size',
#   'bigger',
#   'normally',
#   'would',
#   'great',
#   'super',
#   'cute',
#   'jean',
#   'sexy',
#   'dress',
#   'great',
#   'jessica'],
#  ['item',
#   'expected',
#   'description',
#   'quality',
#   'expected',
#   'pleased',
#   'however',
#   'bought',
#   'size',
#   'large',
#   'safe',
#   'small',
#   'barely',
#   'it',
#   'way',
#   'feared',
#   'x',
#   'would',
#   'i',
#   'bought',
#   'x',
#   'know',
#   'sized'],
#  ['love',
#   'shoe',
#   'totally',
#   'cute',
#   'draw',
#   'back',
#   'kinda',
#   'like',
#   'satin',
#   'paper',
#   'soft',
#   'thought',
#   'would',
#   'great',
#   'none'],
#  ['good', 'quality', 'workmanship', 'authentic', 'looking', 'size', 'easy'],
#  ['these',
#   'shoe',
#   'exceeded',
#   'expectation',
#   'lightweight',
#   'sol',
#   'made',
#   'kind',
#   'stiff',
#   'foam',
#   'instead',
#   'solid',
#   'rubber',
#   'time',
#   'tell',
#   'wear',
#   'compared',
#   'rubber',
#   'shoe',
#   'noticeably',
#   'lighter',
#   'last',
#   'pair',
#   'owned',
#   'they',
#   'look',
#   'good',
#   'comfortable',
#   'little',
#   'break',
#   'time',
#   'like',
#   'look',
#   'safe',
#   'disappointed',
#   'build',
#   'feel'],
#  ['love',
#   'soft',
#   'comfortable',
#   'green',
#   'robe',
#   'received',
#   'last',
#   'year',
#   'mother',
#   'whenever',
#   'wear',
#   'want',
#   'relax',
#   'magazine',
#   'watch',
#   'fall',
#   'asleep',
#   'matching',
#   'green',
#   'slipper',
#   'complete',
#   'feel',
#   'really',
#   'feel',
#   'pampered',
#   'never',
#   'knew',
#   'could',
#   'feel',
#   'good',
#   'wearing',
#   'robe',
#   'especially',
#   'since',
#   'really',
#   'robe',
#   'wearer',
#   'receiving',
#   'wonderful',
#   'plush',
#   'robe',
#   'excellent',
#   'product',
#   'great',
#   'gift'],
#  ['panty',
#   'great',
#   'wash',
#   'wash',
#   'great',
#   'quality',
#   'smooth',
#   'dress',
#   'pant'],
#  ['searched',
#   'internet',
#   'particular',
#   'type',
#   'sock',
#   'like',
#   'discovered',
#   'longer',
#   'manufactured',
#   'i',
#   'went',
#   'amazon',
#   'offered',
#   'decided',
#   'gold',
#   'the',
#   'price',
#   'excellent',
#   'like',
#   'much',
#   'finicky',
#   'thing',
#   'real',
#   'something',
#   'i',
#   'happy',
#   'amazon',
#   'offered',
#   'price',
#   'meant',
#   'would',
#   'huge',
#   'loss',
#   'work',
#   'son',
#   'looked',
#   'price',
#   'sock',
#   'department',
#   'store',
#   'nearby',
#   'discovered',
#   'amazon',
#   'price',
#   'good',
#   'know',
#   'need',
#   'thank',
#   'amazon'],
#  ['product',
#   'junkie',
#   'never',
#   'would',
#   'believed',
#   'could',
#   'stuff',
#   'amazing',
#   'take',
#   'much',
#   'space',
#   'assorted',
#   'bag',
#   'i',
#   'using',
#   'i',
#   'getting',
#   'sister'],
#  ['absolutely', 'comfortable', 'heel', 'closet'],
#  ['shocked',
#   'forgot',
#   'write',
#   'review',
#   'jean',
#   'love',
#   'jean',
#   'they',
#   'favorite',
#   'jean',
#   'perfect',
#   'allows',
#   'room',
#   'breathe',
#   'love',
#   'wearing',
#   'jean',
#   'boot',
#   'daily',
#   'basis',
#   'say',
#   'enough',
#   'tell',
#   'everyone',
#   'even',
#   'petite',
#   'woman',
#   'fit',
#   'far',
#   'better',
#   'anything',
#   'could',
#   'find',
#   'local',
#   'store',
#   'completely',
#   'satisfied',
#   'they',
#   'also',
#   'modern',
#   'look'],
#  ['bought',
#   'item',
#   'boyfriend',
#   'tailgaiting',
#   'experience',
#   'year',
#   'since',
#   'season',
#   'ticket',
#   'loves',
#   'everything',
#   'especially',
#   'fact',
#   'bears'],
#  ['they',
#   'look',
#   'nice',
#   'really',
#   'well',
#   'however',
#   'soft',
#   'like',
#   'clarks'],
#  ['to',
#   'send',
#   'back',
#   'first',
#   'pair',
#   'because',
#   'needed',
#   'bigger',
#   'size',
#   'received',
#   'second',
#   'pair',
#   'credit',
#   'the',
#   'first',
#   'pair',
#   'promptly',
#   'pair',
#   'just',
#   'right',
#   'will',
#   'definately'],
#  ['shoe',
#   'lovely',
#   'classy',
#   'comfortable',
#   'thinking',
#   'getting',
#   'another',
#   'colour'],
#  ['kind',
#   'kind',
#   'skirt',
#   'like',
#   'nifty',
#   'mini',
#   'string',
#   'uncomfortable',
#   'outfit',
#   'look',
#   'good',
#   'girlfriend',
#   'look',
#   'good',
#   'look',
#   'good'],
#  ['these',
#   'great',
#   'girl',
#   'sock',
#   'besides',
#   'economical',
#   'feel',
#   'good',
#   'wash',
#   'good',
#   'stylish',
#   'fall',
#   'they',
#   'look',
#   'great',
#   'jean',
#   'khaki',
#   'ordered',
#   'several',
#   'pair',
#   'different',
#   'color',
#   'true',
#   'value'],
#  ['unfortunately',
#   'never',
#   'received',
#   'product',
#   'purchased',
#   'company',
#   'claimed',
#   'sent',
#   'usps',
#   'never',
#   'received',
#   'far',
#   'company',
#   'concerned',
#   'money',
#   'spent',
#   'plus',
#   'product',
#   'received',
#   'satisfaction'],
#  ['son',
#   'january',
#   'resist',
#   'cute',
#   'little',
#   'shoe',
#   'even',
#   'though',
#   'month',
#   'wait',
#   'little',
#   'what',
#   'well',
#   'made',
#   'product'],
#  ['these', 'keep', 'foot', 'warm', 'toastie', 'will', 'want', 'wear'],
#  ['jacket',
#   'super',
#   'handsome',
#   'comfortable',
#   'stitching',
#   'sleeve',
#   'mended',
#   'easy',
#   'good',
#   'deal'],
#  ['friend',
#   'suggested',
#   'shoe',
#   'waltzing',
#   'around',
#   'neighborhood',
#   'never',
#   'forget'],
#  ['got', 'jacket', 'last', 'week', 'liked', 'price', 'paid'],
#  ['these',
#   'wellies',
#   'rubber',
#   'boot',
#   'show',
#   'stopper',
#   'get',
#   'comment',
#   'smashing',
#   'look',
#   'functional',
#   'wear',
#   'garden',
#   'beach',
#   'walk',
#   'pretty',
#   'high',
#   'water',
#   'without',
#   'getting',
#   'comfortable',
#   'long',
#   'period',
#   'walking'],
#  ['boot',
#   'beautiful',
#   'foot',
#   'wide',
#   'uncomfortable',
#   'break',
#   'price',
#   'reasonable',
#   'hope',
#   'wear',
#   'soon'],
#  ['one',
#   'kind',
#   'handbag',
#   'great',
#   'night',
#   'kick',
#   'unbeatable',
#   'price',
#   'genuine',
#   'item'],
#  ['missed',
#   'late',
#   'knee',
#   'suede',
#   'boot',
#   'got',
#   'they',
#   'great',
#   'thing',
#   'could',
#   'much',
#   'improved',
#   'heel',
#   'they',
#   'thing',
#   'wear',
#   'i',
#   'resoled',
#   'ammazon',
#   'price',
#   'good',
#   'still',
#   'steal'],
#  ['great', 'shirt', 'working', 'clears', 'away', 'sweat', 'loose', 'fitting'],
#  ['purchased',
#   'boot',
#   'daughter',
#   'bought',
#   'pair',
#   'younger',
#   'sister',
#   'fell',
#   'love',
#   'look',
#   'tried',
#   'local',
#   'sporting',
#   'store',
#   'loved',
#   'hugged',
#   'felt',
#   'foot',
#   'would',
#   'color',
#   'rainbow',
#   'asked'],
#  ['arrived',
#   'fast',
#   'time',
#   'day',
#   'thanks',
#   'high',
#   'quality',
#   'product',
#   'fast',
#   'arrival'],
#  ['baby',
#   'love',
#   'kick',
#   'they',
#   'came',
#   'quick',
#   'would',
#   'recomend',
#   'anyone'],
#  ['slipper', 'expected', 'with', 'month', 'say'],
#  ['these',
#   'boot',
#   'warm',
#   'soft',
#   'usually',
#   'wear',
#   '5',
#   'ordered',
#   'size',
#   'even',
#   'though',
#   'recommend',
#   'sizing',
#   'half',
#   'size',
#   'perfectly',
#   'awesome',
#   'cheaper',
#   'alternative',
#   'uggs'],
#  ['exactly',
#   'husband',
#   'admired',
#   'macy',
#   'paid',
#   'convenience',
#   'delivered',
#   'home',
#   'without',
#   'husband',
#   'knowledge',
#   'thrilled',
#   'jacket'],
#  ['recipient', 'satisfied', 'blanket', 'initial'],
#  ['wanted',
#   'pair',
#   'since',
#   'little',
#   'girl',
#   'glamorous',
#   'girly',
#   'sexy',
#   'surprised',
#   'comfortable',
#   'foot',
#   'they',
#   'really',
#   'feel',
#   'like',
#   'slipper',
#   'heel',
#   'bonus',
#   'normally',
#   'wear',
#   '6',
#   'little',
#   'snug',
#   'so',
#   'glad',
#   'bought',
#   'pair',
#   'black',
#   'pink',
#   'next'],
#  ['bought',
#   'gift',
#   'husband',
#   'previously',
#   'bought',
#   'eletronic',
#   'rack',
#   'thing',
#   'fell',
#   'apart',
#   'trying',
#   'installed',
#   'these',
#   'ready',
#   'right',
#   'assembly',
#   'required',
#   'took',
#   'space',
#   'closet',
#   '4',
#   'hanger',
#   'wrapped',
#   'around',
#   'made',
#   'collection',
#   'managable',
#   'easy',
#   'select',
#   'cushioned',
#   'hook',
#   'ensure',
#   'slip',
#   'also',
#   'damaged',
#   'breeze',
#   'organize',
#   'vast',
#   'collection',
#   'loving',
#   'product'],
#  ['ordered',
#   'extenders',
#   'since',
#   'pregnant',
#   'trouble',
#   'fitting',
#   'thing',
#   'working',
#   'great',
#   'recevied',
#   'quickly',
#   'exactly',
#   'expected',
#   'thanks'],
#  ['shirt',
#   'first',
#   'under',
#   'armour',
#   'purchase',
#   'took',
#   'chance',
#   'ordering',
#   'without',
#   'ever',
#   'trying',
#   'under',
#   'armour',
#   'dissatisfied',
#   'favorite',
#   'tee',
#   'shirt',
#   'positive',
#   'side',
#   'weight',
#   'fabric',
#   'good',
#   'exercising',
#   'especially',
#   'would',
#   'good',
#   'single',
#   'layer',
#   'outside'],
#  ['son',
#   'favorite',
#   'color',
#   'orange',
#   'finding',
#   'orange',
#   'lunch',
#   'year',
#   'tough',
#   'find',
#   'found',
#   'lunch',
#   'it',
#   'perfect',
#   'high',
#   'qualtiy',
#   'great',
#   'price',
#   'fast',
#   'delivery',
#   'completely',
#   'satisfied',
#   'definately',
#   'order',
#   'next',
#   'year'],
#  ['2nd',
#   'type',
#   'curler',
#   'last',
#   'stayed',
#   'three',
#   'year',
#   'they',
#   'good',
#   'stopped',
#   'using',
#   'home',
#   'use',
#   'type',
#   'daily',
#   'heat',
#   'fast',
#   'great',
#   'lasting',
#   'curl',
#   'particularly',
#   'hard',
#   'curl',
#   'fine',
#   'hair',
#   'even',
#   'need',
#   'leave',
#   'long'],
#  ['bought',
#   'boot',
#   'varying',
#   'terrain',
#   'temperature',
#   'condition',
#   'stable',
#   'comfortable',
#   'provides',
#   'good',
#   'traction',
#   'warm',
#   'without',
#   'sweaty',
#   'would',
#   'strongly',
#   'recommend',
#   'boot'],
#  ['love',
#   'shoe',
#   'quite',
#   'comfortable',
#   'even',
#   'though',
#   'heel',
#   'little',
#   'higher',
#   'like',
#   'they',
#   'beautiful',
#   'color',
#   'something',
#   'always',
#   'quite',
#   'catching',
#   'happened',
#   'well',
#   'suit',
#   'purchased',
#   'month'],
#  ['shirt', 'really', 'made', 'arrived', 'shortly', 'placing', 'order'],
#  ['great',
#   'pair',
#   'shoe',
#   'good',
#   'collection',
#   'subtle',
#   'silver',
#   'look',
#   'absolutely',
#   'delicate',
#   'foot',
#   'one',
#   'size',
#   'smaller',
#   'normal',
#   'usually',
#   'wear',
#   '5m',
#   'turned',
#   'small',
#   'fit',
#   'jut',
#   'little',
#   'a',
#   'would',
#   'better',
#   'dont',
#   'patience',
#   'return',
#   'i',
#   'gonna',
#   'keep',
#   'lovely',
#   'pair',
#   'shoe'],
#  ['earmuff', 'nice', 'quality', 'color', 'perfect', 'daughter'],
#  ['pleased',
#   'soft',
#   'briefcase',
#   'purchased',
#   'much',
#   'easier',
#   'handle',
#   'hard',
#   'would',
#   'purchase',
#   'another',
#   'item',
#   'manufactuer',
#   'i',
#   'need',
#   'something',
#   'else'],
#  ['worst',
#   'foot',
#   'ran',
#   'first',
#   'marathon',
#   'panic',
#   'long',
#   'march',
#   'first',
#   'part',
#   'april',
#   'going',
#   'quit',
#   'foot',
#   'hurt',
#   'training',
#   'downhill',
#   'therefore',
#   'landed',
#   'ball',
#   'foot',
#   'ouch',
#   'think',
#   'would',
#   'better',
#   'nothing',
#   'wear',
#   'top',
#   'line',
#   'shoe',
#   'desparate',
#   'found',
#   'asics',
#   '2110',
#   'shoe',
#   'woman',
#   'felt',
#   'better',
#   'support',
#   'plus',
#   'cushion',
#   'needed',
#   'sore',
#   'foot',
#   'awesome',
#   'shoe',
#   'i',
#   'finished',
#   'marathon',
#   'i',
#   'done',
#   'without'],
#  ['these',
#   'nice',
#   'sweatshirt',
#   'good',
#   'quality',
#   'price',
#   'half',
#   'might',
#   'champion',
#   'brand',
#   'oversized',
#   'order',
#   'normal',
#   'size',
#   'count',
#   'much',
#   'shrinkage'],
#  ['look', 'nice', 'material', 'little', 'original'],
#  ['raglan',
#   'sleeve',
#   'make',
#   'edgy',
#   'wearing',
#   'plain',
#   'shirt',
#   'good',
#   'quality',
#   'price',
#   'usually',
#   'wear',
#   'medium',
#   'ordered',
#   'good',
#   'fitted',
#   'tight'],
#  ['must',
#   'shoe',
#   'bunion',
#   'hammertoe',
#   'sufferer',
#   'also',
#   'sweaty',
#   'foot',
#   'excellent',
#   'choice',
#   'share',
#   'problem',
#   'large',
#   'box',
#   'excellent',
#   'webbing',
#   'ventilation',
#   'good',
#   'looking',
#   'comfortable',
#   'shoe',
#   'qualification',
#   'stand',
#   'foot',
#   'lot',
#   'walking',
#   'want',
#   'pick',
#   'shoe',
#   'support',
#   'lightweight',
#   'shoe',
#   'lack',
#   'support',
#   'heavier',
#   'athletic',
#   'shoe',
#   'would',
#   'offer',
#   'type',
#   'shoe',
#   'usually',
#   'harder',
#   'bunion',
#   'foot',
#   'extremely'],
#  ['finally',
#   'found',
#   'quality',
#   'brand',
#   'swimsuit',
#   'order',
#   'line',
#   'know',
#   'daily',
#   'swimmer',
#   'long',
#   'bodied',
#   'particular',
#   'style',
#   'great',
#   'arrived',
#   'arrived',
#   'quickly',
#   'within',
#   'four',
#   'shipping',
#   'free',
#   'lycra',
#   'material',
#   'resilient',
#   'i',
#   'know',
#   'given',
#   'chlorine',
#   'bashing',
#   'suit',
#   'please',
#   'continue',
#   'sell',
#   'particular',
#   'item',
#   'price',
#   'lower',
#   'sport',
#   'store',
#   'thanks'],
#  ['just',
#   'received',
#   'pair',
#   'deer',
#   'stags',
#   'father',
#   'really',
#   'never',
#   'heard',
#   'they',
#   'comfortable',
#   'dress',
#   'shoe',
#   'ever',
#   'worn',
#   'good',
#   'around',
#   'office',
#   'factory',
#   'floor',
#   'field',
#   'slip',
#   'resistant'],
#  ['experience',
#   'compression',
#   'short',
#   'pleased',
#   'product',
#   'fabric',
#   'lose',
#   'compression',
#   'time',
#   'although',
#   'short',
#   'time',
#   'good',
#   'fabric',
#   'comfortable',
#   'gotten',
#   'habit',
#   'sleeping',
#   'work',
#   'great',
#   'keeping',
#   'toasty',
#   'wish',
#   'product',
#   'like',
#   'around',
#   'year',
#   'played',
#   'college',
#   'soccer'],
#  ['shoe',
#   'awesome',
#   'daughter',
#   'loves',
#   'business',
#   'done',
#   'professional',
#   'manner',
#   'easy',
#   'transaction'],
#  ['purchased', 'girlfriend', 'told', 'well', 'happy', 'glad', 'good', 'price'],
#  ['heck',
#   'time',
#   'trying',
#   'find',
#   'would',
#   'slip',
#   'shoulder',
#   'would',
#   'support',
#   'breast',
#   'one',
#   'support',
#   'better',
#   'sport',
#   'give',
#   'beautiful',
#   'shape',
#   'bustline',
#   'looking',
#   'well',
#   'rounded',
#   'shape',
#   'conical',
#   'sloped',
#   'key',
#   'propper',
#   'went',
#   '34dd',
#   'sized',
#   'changed',
#   'getting',
#   'well',
#   'fitted',
#   'if',
#   'pull',
#   'band',
#   'inch',
#   'body',
#   'wearing',
#   'wrong',
#   'size',
#   'supposed',
#   'snug',
#   'hold',
#   'everything',
#   'place',
#   'take',
#   'little',
#   'getting',
#   'used',
#   'wearing',
#   'something',
#   'tight',
#   'bounce',
#   'jiggle',
#   'pull',
#   'falling',
#   'bra',
#   'strap',
#   'anymore',
#   'bought',
#   'september',
#   'went',
#   'back',
#   'purchased',
#   'october',
#   'wear',
#   'purchase',
#   'exact',
#   'thing',
#   'hand',
#   'wash',
#   'machine',
#   'wash',
#   'delicate',
#   'wearing',
#   'lingerie',
#   'soap',
#   'line',
#   'they',
#   'still',
#   'look',
#   'band',
#   'little',
#   'concerned',
#   'itty',
#   'bitty',
#   'plastic',
#   'front',
#   'closure',
#   'bursting',
#   'band',
#   'snug',
#   'still',
#   'holding',
#   'together',
#   'i',
#   'also',
#   'concerned',
#   'sheer',
#   'fabric',
#   'lasting',
#   'i',
#   'tear',
#   'run',
#   'poked'],
#  ['before',
#   'seeing',
#   'little',
#   'skeptical',
#   'huge',
#   'button',
#   'after',
#   'wearing',
#   'felt',
#   'hardly',
#   'noticable',
#   'bought',
#   'brown',
#   'version',
#   '99',
#   'i',
#   'thought',
#   'well',
#   'worth',
#   'jacket',
#   'surprisingly',
#   'wind',
#   'resistant',
#   'ideal',
#   'cold',
#   'weather',
#   'pocket',
#   'either',
#   'side',
#   'huge',
#   'practically',
#   'store',
#   'couple',
#   'cell',
#   'phone'],
#  ['pros'],
#  ['these',
#   'shoe',
#   'best',
#   'like',
#   'removable',
#   'wheel',
#   'could',
#   'heel',
#   'school'],
#  ['once',
#   'traveling',
#   'big',
#   'blister',
#   'heel',
#   'needed',
#   'something',
#   'heel',
#   'happened',
#   'pair',
#   'crocs',
#   'since',
#   'strap',
#   'moved',
#   'forward',
#   'look',
#   'like',
#   'trim',
#   'front',
#   'pleasantly',
#   'surprised',
#   'crocs',
#   'cushiony',
#   'soft',
#   'like',
#   'walking',
#   'also',
#   'material',
#   'insulating',
#   'enough',
#   'keep',
#   'foot',
#   'warm',
#   'air',
#   'hole',
#   'ventilate',
#   'enough',
#   'foot',
#   'sweaty',
#   'either'],
#  ['men',
#   'silk',
#   'purchased',
#   'year',
#   'husband',
#   'best',
#   'fabric',
#   'nice',
#   'heavy',
#   'weight',
#   'survives',
#   'machine',
#   'washing',
#   'well',
#   'after',
#   'reading',
#   'customer',
#   'review',
#   'purchased',
#   'medium',
#   'size',
#   'person',
#   'usually',
#   'wear',
#   'size',
#   'occasionally',
#   'it',
#   'turned',
#   'small',
#   'i',
#   'would',
#   'recommend',
#   'going',
#   'size'],
#  ['pregnant',
#   'nursing',
#   'last',
#   'year',
#   'tried',
#   'different',
#   'nursing',
#   'several',
#   'month',
#   'absolutely',
#   'love',
#   'reasonably',
#   'happy',
#   'bravado',
#   'line',
#   'general',
#   'hold',
#   'well',
#   'stay',
#   'comfortable',
#   'remain',
#   'supportive',
#   'time',
#   'fond',
#   'sport',
#   'styling',
#   'original',
#   'i',
#   'often',
#   'size',
#   '36',
#   'c',
#   'depending',
#   'maker',
#   'habit',
#   'nursing',
#   'right',
#   'side',
#   'left',
#   'often',
#   'breast',
#   'larger',
#   '36c',
#   'comfortably',
#   'noticeable',
#   'bunching',
#   'line',
#   'nasty',
#   'spillover',
#   'long',
#   'feeding',
#   'i',
#   'wear',
#   'fairly',
#   'fitted',
#   'cotten',
#   'shirt',
#   'every',
#   'year',
#   'really',
#   'important',
#   'fit',
#   'smoothly',
#   'nursing',
#   'i',
#   'found',
#   'work',
#   'well',
#   'shirt',
#   'mimi',
#   'brand',
#   'one',
#   'cost',
#   'much',
#   'hold',
#   'shape',
#   'long',
#   'basically',
#   'comfortable',
#   'easy',
#   'last'],
#  ['very',
#   'comfortable',
#   'durable',
#   'would',
#   'wear',
#   'outside',
#   'although',
#   'long',
#   'walk',
#   'sole',
#   'durable',
#   'enough',
#   'walking',
#   'mailbox',
#   'taking',
#   'brief',
#   'jaunt',
#   'recommend',
#   'looking',
#   'inexpensive',
#   'durable',
#   'slipper'],
#  ['excellent',
#   'product',
#   'item',
#   'arrived',
#   'fast',
#   'exactly',
#   'described',
#   'works',
#   'like',
#   'charm',
#   'haven',
#   'tsa',
#   'open',
#   'lock'],
#  ['beautiful',
#   'people',
#   'shoe',
#   'sexy',
#   'think',
#   'could',
#   'wear',
#   'high',
#   'wedge',
#   'heel',
#   'however',
#   'wrong',
#   'thankful',
#   'fun',
#   'shoe',
#   'look',
#   'great',
#   'gold',
#   'i',
#   'love',
#   'wearing'],
#  ['bought',
#   'couple',
#   'month',
#   'already',
#   'test',
#   'went',
#   'hiking',
#   'waterfall',
#   'mexico',
#   'ended',
#   'covered',
#   'new',
#   'shoe',
#   'included',
#   'worried',
#   'would',
#   'spoiled',
#   'really',
#   'mud',
#   'then',
#   'washed',
#   'running',
#   'water',
#   'dirt',
#   'gone',
#   'besides',
#   'really',
#   'comfortable',
#   'great',
#   'know',
#   'type',
#   'terrain'],
#  ['love',
#   'shoe',
#   'look',
#   'elegant',
#   'foot',
#   'little',
#   'toe',
#   'cleavage',
#   'always',
#   'plus',
#   'make',
#   'sure',
#   'half',
#   'size',
#   'little',
#   'snug',
#   'front',
#   'take',
#   'couple',
#   'wear',
#   'break'],
#  ['megasoft',
#   'bathrobe',
#   'pretty',
#   'soft',
#   'thick',
#   'relative',
#   'bathrobe',
#   'nice',
#   'feel',
#   'bathrobe',
#   'made',
#   'japanese',
#   'yarn',
#   'yarn',
#   'made',
#   'cotton',
#   'bathrobe',
#   'made',
#   'cotton',
#   'cotton',
#   'course',
#   'strinks',
#   'wash',
#   'strinkage',
#   'tolerable',
#   'purchased',
#   'expresso',
#   'color',
#   'wash',
#   'color',
#   'faded',
#   'expected',
#   'overall',
#   'satisfied',
#   'purchase',
#   'would',
#   'purchase',
#   'choice'],
#  ['bought',
#   'several',
#   'month',
#   'ross',
#   'dress',
#   'less',
#   'oregon',
#   '99',
#   'love',
#   'bought',
#   'white',
#   'since',
#   'choice',
#   'love',
#   'comfort',
#   'think',
#   'strap',
#   'stay',
#   'foot',
#   'much',
#   'better',
#   'older',
#   'birk',
#   'style',
#   'wide',
#   'sloppy',
#   'foot',
#   'strap',
#   'cushioned',
#   'hurt',
#   'toe',
#   'wear',
#   'size',
#   '8'],
#  ['bought',
#   'husband',
#   'loves',
#   'they',
#   'well',
#   'made',
#   'super',
#   'comfortable',
#   'liked',
#   'much',
#   'bought',
#   'another',
#   'pair',
#   'different',
#   'color',
#   'highly',
#   'recommended'],
#  ['one', 'comfortable', 'shoe', 'ever', 'owned', 'excellent', 'quality'],
#  ['son',
#   'love',
#   'shoe',
#   'they',
#   'comfortable',
#   'stylish',
#   'they',
#   'show',
#   'dirt',
#   'like',
#   'shoe',
#   'they',
#   'look',
#   'made',
#   'well',
#   'designed',
#   'nice'],
#  ['tiffany',
#   'version',
#   'super',
#   'expensive',
#   'these',
#   'clean',
#   'simple',
#   'they',
#   'job',
#   'done'],
#  ['ordering',
#   'online',
#   'able',
#   'clothing',
#   'risky',
#   'paid',
#   'purchase',
#   'wish',
#   'hand',
#   'wash'],
#  ['columbia', 'sport', 'sandal', 'great', 'bought', 'three', 'year', 'kid'],
#  ['could',
#   'find',
#   'slipper',
#   'local',
#   'store',
#   'two',
#   'pair',
#   'worn',
#   'wanted',
#   'exactly',
#   'item',
#   'ordered',
#   'arrived',
#   'love',
#   'easy',
#   'customer',
#   'friendly',
#   'process'],
#  ['love',
#   'boot',
#   'high',
#   'platform',
#   'make',
#   'unaccustomed',
#   'little',
#   'teeter',
#   'great',
#   'look',
#   'leather',
#   'detail',
#   'pair',
#   'exceptional',
#   'green',
#   'leather',
#   'inside',
#   'really',
#   'like',
#   'i',
#   'pair',
#   'shoe'],
#  ['quick', 'service', 'shoe', 'discontinued', 'hard', 'find', 'size'],
#  ['received',
#   'slipper',
#   'christmas',
#   'december',
#   '2005',
#   'got',
#   'pine',
#   'green',
#   'nice',
#   'looking',
#   'slipper',
#   'comfort',
#   'ordering',
#   'another',
#   'pair',
#   'charcoal',
#   'want',
#   'pair',
#   'place',
#   'live',
#   'comfort',
#   'home',
#   'bill',
#   'good',
#   'value',
#   'well'],
#  ['really',
#   'like',
#   'case',
#   'perfectly',
#   'rattle',
#   'around',
#   'anything',
#   'plug',
#   'button',
#   'still',
#   'accessible',
#   'easy',
#   'look',
#   'great'],
#  ['purchased',
#   'pair',
#   'boot',
#   'teenage',
#   'daughter',
#   'life',
#   'type',
#   'like',
#   'boot',
#   'looked',
#   'store',
#   'online',
#   'shoe',
#   'site',
#   'uggs',
#   'alternative',
#   'season',
#   'find',
#   'size',
#   'saw',
#   'amazon',
#   'size',
#   'thought',
#   'they',
#   'definitely',
#   'worth',
#   'they',
#   'warm',
#   'comfortable',
#   'uggs',
#   'since',
#   'price',
#   'good',
#   'able',
#   'two',
#   'pair',
#   'they',
#   'nicely',
#   'made',
#   'comfortable',
#   'attractive',
#   'wear',
#   'almost',
#   'everyday',
#   'proving',
#   'pretty',
#   'durable',
#   'really',
#   'choosy',
#   'footwear',
#   'absolutely',
#   'love',
#   'boot'],
#  ['made',
#   'bone',
#   'head',
#   'move',
#   'bought',
#   'it',
#   'cost',
#   'much',
#   'send',
#   'shirt',
#   'these',
#   'people',
#   'areally',
#   'good',
#   'shirt',
#   'thin',
#   'stiched',
#   'well'],
#  ['your',
#   'company',
#   'pleasure',
#   'work',
#   'thanks',
#   'enjoy',
#   'wearing',
#   'swimsuit',
#   'ordered'],
#  ['everyone',
#   'loved',
#   'glass',
#   'fashioned',
#   'banquet',
#   'they',
#   'completed',
#   'outfit',
#   'great',
#   'price',
#   'speedy',
#   'delivery',
#   'really',
#   'needed'],
#  ['good',
#   'construction',
#   'material',
#   'price',
#   'size',
#   'seems',
#   'different',
#   'v',
#   'unless',
#   'asymmetrical',
#   'noticed',
#   'nice',
#   'sheepskin',
#   'material',
#   'hoping',
#   'last',
#   'longer',
#   'previous',
#   'i',
#   'purchased',
#   'acorn'],
#  ['good',
#   'color',
#   'visibility',
#   'nicely',
#   'structured',
#   'warmth',
#   'applicable',
#   'unspeakable',
#   'inhuman',
#   'frigidites',
#   'amerikan',
#   'north'],
#  ['very',
#   'warm',
#   'comfortable',
#   'price',
#   'price',
#   'really',
#   'nice',
#   'look',
#   'good',
#   'feel',
#   'comfy',
#   'keep',
#   'warm',
#   'wind',
#   'without',
#   'reducing',
#   'hearing',
#   'least'],
#  ['thing', 'away', 'christmas', 'gift', 'nice', 'product', 'nice', 'tied'],
#  ['speedy', 'delivery', 'product', 'stated', 'would', 'agai'],
#  ['finally',
#   'looking',
#   'good',
#   'bust',
#   'enhancer',
#   'several',
#   'year',
#   'these',
#   'enhancer',
#   'well',
#   'shaped',
#   'incredibly',
#   'comfortable',
#   'when',
#   'ordering',
#   'ahead',
#   'b'],
#  ['great',
#   'hard',
#   'side',
#   'suitcase',
#   'price',
#   'basic',
#   'simple',
#   'seems',
#   'quite',
#   'durable',
#   'functional',
#   'use',
#   'taking',
#   'folding',
#   'bicycle',
#   'travelling',
#   'enough',
#   'bike',
#   'small',
#   'enough',
#   'airline',
#   'charge',
#   'premium',
#   'checking',
#   'roll',
#   'well',
#   'built',
#   'wheel',
#   'unlike',
#   'smaller',
#   'cousin',
#   'oyster',
#   'roll',
#   'much',
#   'stability',
#   'wide',
#   'stance',
#   'reason',
#   'give',
#   'star',
#   'sometimes',
#   'wide',
#   'rolling',
#   'stance',
#   'hassle',
#   'g',
#   'going',
#   'narrow',
#   'gate',
#   'subway',
#   'similar',
#   'built',
#   'lock',
#   'lock',
#   'word',
#   'useless',
#   'flight'],
#  ['these',
#   'shoe',
#   'comfortable',
#   'cute',
#   'gotten',
#   'compliment',
#   'like',
#   'school',
#   'pony',
#   'look'],
#  ['use',
#   'sock',
#   'running',
#   'well',
#   'cushioned',
#   'comfortable',
#   'also',
#   'withstand',
#   'frequent',
#   'laundry',
#   'without',
#   'loosing',
#   'quality'],
#  ['beading',
#   'fantastic',
#   'cute',
#   'color',
#   'even',
#   'exquisite',
#   'person',
#   'big',
#   'enough',
#   'hold',
#   'little',
#   'money',
#   'lipstick',
#   'perfect',
#   'going',
#   'night'],
#  ['best',
#   'small',
#   'front',
#   'pocket',
#   'wallet',
#   'available',
#   'other',
#   'front',
#   'pocket',
#   'wallet',
#   'gimmicky',
#   'design',
#   'work',
#   'well',
#   'designed',
#   'pattern',
#   'full',
#   'size',
#   'wallet',
#   'reduced',
#   'inch',
#   'holds',
#   'three',
#   'card',
#   'bill',
#   'well',
#   'little',
#   'room',
#   'card',
#   'business',
#   'card',
#   'great'],
#  ['these',
#   'best',
#   'windproof',
#   'liner',
#   'glove',
#   'freaked',
#   'thinking',
#   'discontinued',
#   'thought',
#   'made',
#   'gore',
#   'windstopper',
#   'find',
#   'said',
#   'made',
#   'gore',
#   'windstopper',
#   'actually',
#   'polarguard',
#   'windbloc',
#   'case',
#   'freak',
#   'becuase',
#   'think',
#   'might',
#   'able',
#   'something',
#   'realize',
#   'much',
#   'like',
#   'thing'],
#  ['great',
#   'comfortable',
#   'work',
#   'minimizer',
#   'great',
#   'larger',
#   'size',
#   'exercise',
#   'provides',
#   'great',
#   'support',
#   'even',
#   'good',
#   'enough',
#   'running',
#   'treadmill',
#   'lasted',
#   'several',
#   'year',
#   'impressed',
#   'looked',
#   'number',
#   'bra',
#   'found',
#   'site',
#   'purchase',
#   'half',
#   'paid',
#   'mall',
#   'i',
#   'wear',
#   'everyday'],
#  ['fits', 'great', 'quality', 'great', 'sale', 'price', 'lucky', 'pay'],
#  ['good',
#   'quality',
#   'great',
#   'price',
#   'bought',
#   'year',
#   'son',
#   'perfect',
#   'item',
#   'backorder',
#   'still',
#   'received',
#   'week'],
#  ['munsingwear',
#   'definitely',
#   'comfortable',
#   'best',
#   'fitting',
#   'brief',
#   'ever',
#   'worn'],
#  ['love',
#   'crocs',
#   'they',
#   'much',
#   'comfortable',
#   'original',
#   'style',
#   'like',
#   'tone',
#   'color',
#   'combo',
#   'wear',
#   'even',
#   'winter'],
#  ['love',
#   'shirt',
#   'birthday',
#   'present',
#   'we',
#   'impressed',
#   'quality',
#   'definitely',
#   'amazon',
#   'site'],
#  ['arm',
#   'like',
#   'gorilla',
#   'pleasantly',
#   'surprised',
#   'length',
#   'sleeve',
#   'they',
#   'even',
#   'appendage',
#   'nicely',
#   'followed',
#   'advice',
#   'reviewer',
#   'glad',
#   'large',
#   'perfect',
#   'pretty',
#   'slender',
#   'material',
#   'fairly',
#   'thin',
#   'overall',
#   'i',
#   'say',
#   'shirt',
#   'good',
#   'value'],
#  ['happy',
#   'swimsuit',
#   'delivery',
#   'stated',
#   'fits',
#   'wonderfully',
#   'problem',
#   'wearing',
#   'little',
#   'edge',
#   'cup',
#   'showing',
#   'tucked',
#   'whenever',
#   'noticeable',
#   'happy',
#   'suit',
#   'nicely',
#   'little',
#   'worried',
#   'return',
#   'different',
#   'size',
#   'paying',
#   'shipping',
#   'size',
#   'ordered',
#   'size',
#   'normally',
#   'wear',
#   'said',
#   'great'],
#  ['well',
#   'found',
#   'true',
#   'size',
#   'offer',
#   'great',
#   'support',
#   'much',
#   'rather',
#   'price',
#   'outrageous',
#   'price',
#   'paid',
#   'sport',
#   'bra',
#   'past',
#   'offered',
#   'near',
#   'support',
#   'held',
#   'well',
#   'jogging'],
#  ['originally', 'started', 'wearing', 'hanky', 'panky', 'thong', 'panty'],
#  ['son', 'love', 'jersey', 'little', 'pricey', 'nice', 'jerse'],
#  ['received',
#   'today',
#   'mail',
#   'pleased',
#   'feel',
#   'foot',
#   'comfortable',
#   'easy',
#   'slide'],
#  ['body', 'show', 'mean', 'wear', 'alone'],
#  ['great',
#   'price',
#   'another',
#   'pair',
#   'shoe',
#   'bought',
#   'elsewhere',
#   'twice',
#   'price',
#   'very',
#   'comfortable',
#   'true',
#   'size'],
#  ['they',
#   'shipped',
#   'almost',
#   'overnight',
#   'daughter',
#   'perfect',
#   'little',
#   'flower',
#   'girl',
#   'trip',
#   'blister',
#   'held',
#   'great',
#   'past',
#   'month',
#   'great',
#   'durability',
#   'dance',
#   'play',
#   'size',
#   '10',
#   'time',
#   'wedding',
#   'shoe',
#   'her',
#   'foot',
#   'fine',
#   'still',
#   'squeeze',
#   'very',
#   'pleased',
#   'good',
#   'value',
#   'these',
#   'exact',
#   'shoe'],
#  ['love', 'clarks', 'get', 'good', 'price', 'amazon'],
#  ['love',
#   'different',
#   'thing',
#   'love',
#   'give',
#   'people',
#   'gift',
#   'else',
#   'thanks'],
#  ['product',
#   'arrives',
#   'shown',
#   'sturdy',
#   'attractive',
#   'leather',
#   'just',
#   'right',
#   'size',
#   'small',
#   'item',
#   'a',
#   'product'],
#  ['these',
#   'stylish',
#   'nice',
#   'perfect',
#   'wear',
#   'pair',
#   'cutoff',
#   'levi',
#   'cutoff',
#   'faded',
#   'frayed',
#   'well',
#   'know',
#   'peal',
#   'reveal',
#   'butterfly',
#   'lace',
#   'panty',
#   'black',
#   'pick',
#   'lace',
#   'back',
#   'like',
#   'instant',
#   'transformation',
#   'outdoor',
#   'girl',
#   'bedroom',
#   'girl',
#   'two',
#   'color',
#   'lingerie',
#   'party',
#   'white',
#   'black',
#   'pink',
#   'model',
#   'i',
#   'imagine',
#   'color',
#   'would',
#   'nice'],
#  ['these',
#   'jean',
#   'extremely',
#   'soft',
#   'comfortable',
#   'like',
#   'child',
#   'place',
#   'merchandise',
#   'quality',
#   'nice',
#   'little',
#   'larger',
#   'brand',
#   'negative',
#   'thought',
#   'material',
#   'little',
#   'thicker',
#   'boy',
#   'tough',
#   'clothes'],
#  ['does',
#   'described',
#   'recommend',
#   'brand',
#   'downst',
#   'fall',
#   'apart',
#   'couple',
#   'wear'],
#  ['great',
#   'wallet',
#   'small',
#   'purse',
#   'purpose',
#   'hold',
#   'card',
#   'small',
#   'zipper',
#   'section',
#   'money',
#   'meant',
#   'complete',
#   'wallet',
#   'love',
#   'small',
#   'purse',
#   'easy',
#   'carry',
#   'around',
#   'shove',
#   'push',
#   'bigger',
#   'wallet',
#   'purse',
#   'room',
#   'anything',
#   'else',
#   'anymore',
#   'love'],
#  ['made',
#   'poopie',
#   'panty',
#   'mean',
#   'love',
#   'camo',
#   '5',
#   'live',
#   'york',
#   'city',
#   'apratmant',
#   'fancy',
#   'stupiodo',
#   'haeds',
#   'im',
#   'army'],
#  ['pair',
#   'several',
#   'year',
#   'incredibly',
#   'lucky',
#   'find',
#   'they',
#   'extremely',
#   'comfortable',
#   'better',
#   'many',
#   'pair',
#   'sneaker',
#   'tried',
#   'they',
#   'worn',
#   'well',
#   'say',
#   'well',
#   'made',
#   'replace',
#   'shoelace',
#   'bit',
#   'polish',
#   'kiwi',
#   'leather',
#   'cleaner',
#   'protector',
# ...
#   'high',
#   'quality',
#   'shoe',
#   'good',
#   'price',
#   't',
#   'macs'],
#  ['merchant',
#   'really',
#   'delivers',
#   'item',
#   'store',
#   'almost',
#   'twice',
#   'price',
#   'really',
#   'expecting',
#   'quality',
#   'item',
#   'crushed',
#   'velvet',
#   'warm',
#   'warm',
#   'goal',
#   'would',
#   'definitely',
#   'recommend',
#   'item',
#   'buy',
#   'another',
#   'color'],
#  ['love',
#   'shoe',
#   'they',
#   'comfy',
#   'look',
#   'good',
#   'price',
#   'steep',
#   'think',
#   'considering',
#   'could',
#   'wear',
#   'practically',
#   'every',
#   'get',
#   'tired',
#   'guess',
#   'worth',
#   'definitely',
#   'considering',
#   'purchasing',
#   'another',
#   'pair',
#   'brown'],
#  ['great', 'company', 'order', 'good', 'product', 'faster', 'order'],
#  ['got',
#   'deeply',
#   'discounted',
#   'price',
#   'clearance',
#   'nearby',
#   'store',
#   'realize',
#   'much',
#   'liked',
#   'decided',
#   'another',
#   'time',
#   'later',
#   'panicked',
#   'make',
#   'writing',
#   'trying',
#   'find',
#   'dang',
#   'ages',
#   'finally',
#   'found',
#   'stoked',
#   'one',
#   'i',
#   'bought',
#   'long',
#   'favorite',
#   'look',
#   'pretty',
#   'like',
#   'reviewer',
#   'mine',
#   'developed',
#   'split',
#   'fabric',
#   'many',
#   'many',
#   'wash',
#   'machine',
#   'ride',
#   'bike',
#   'exercise',
#   'dvds',
#   'etc'],
#  ['these',
#   'without',
#   'question',
#   'best',
#   'panty',
#   'wearing',
#   'slack',
#   'line',
#   'line',
#   'accross',
#   'middle',
#   'behind',
#   'riding',
#   'they',
#   'also',
#   'enough',
#   'show',
#   'moderately',
#   'low',
#   'rise',
#   'pant',
#   'sizing',
#   'true',
#   'maidenform',
#   'pantie',
#   'ever',
#   'bought',
#   'cheaper',
#   'maidenform',
#   'outlet',
#   'store',
#   'still',
#   'well',
#   'worth',
#   'price',
#   'amazon',
#   'lot'],
#  ['gratefully', 'pleased', 'product', 'vendor', 'very', 'pleased'],
#  ['these',
#   'wonderful',
#   'sandal',
#   'tried',
#   'find',
#   'flat',
#   'slingback',
#   'sandal',
#   'store',
#   'avail',
#   'finally',
#   'right',
#   'thing',
#   'went',
#   'online',
#   'great',
#   'sandals',
#   'reasonable',
#   'price',
#   'sorry',
#   'purchase',
#   'very',
#   'stylish',
#   'comfortable'],
#  ['turf',
#   'gear',
#   'initally',
#   'marketed',
#   'football',
#   'player',
#   'well',
#   'think',
#   'year',
#   'bill',
#   'clinton',
#   'became',
#   'president',
#   'last',
#   'time',
#   'donned',
#   'shoulder',
#   'stop',
#   'active',
#   'later',
#   'life',
#   'with',
#   'long',
#   'sleeve',
#   'turf',
#   'gear',
#   'shirt',
#   'under',
#   'armour',
#   'hoping',
#   'product',
#   'would',
#   'live',
#   'description',
#   'long',
#   'sleeve',
#   'shirt',
#   'skin',
#   'tight',
#   'allows',
#   'skin',
#   'breath',
#   'material',
#   'wick',
#   'sweat',
#   'away',
#   'skin',
#   'sounded',
#   'almost',
#   'good',
#   'true',
#   'took',
#   'chance',
#   'anyways'],
#  ['bought',
#   'normally',
#   'wear',
#   'shoe',
#   'without',
#   'orthodic',
#   'insert',
#   'these',
#   'great',
#   'very',
#   'comfortable',
#   'plan',
#   'living',
#   'summer'],
#  ['nice',
#   'soft',
#   'leatherette',
#   'inside',
#   'roomy',
#   'fairly',
#   'accurate',
#   'size',
#   'body',
#   'ratio',
#   'tie',
#   'front',
#   'detail',
#   'stay',
#   'worry',
#   'unraveling',
#   'loosening',
#   'nice',
#   'silver',
#   'buckle',
#   'accent',
#   'strap',
#   'great'],
#  ['cologne',
#   'perfect',
#   'balance',
#   'wood',
#   'sweetness',
#   'overpowering',
#   'masculine',
#   'bought',
#   'boyfriend',
#   'found',
#   'even',
#   'potent',
#   'aa',
#   'great',
#   'fragranc'],
#  ['ordered',
#   'product',
#   'paid',
#   'expedited',
#   'shipping',
#   'later',
#   'arrived',
#   'their',
#   'explanation',
#   'day',
#   'shipping',
#   'day',
#   'shipping',
#   'still',
#   'took',
#   'day',
#   'around',
#   'shipping',
#   'backpack',
#   'missed',
#   'giftee',
#   'shipped',
#   'catch'],
#  ['suit', 'exactly', 'ordered', 'small', 'enough', 'training'],
#  ['once',
#   'traveling',
#   'big',
#   'blister',
#   'heel',
#   'needed',
#   'something',
#   'heel',
#   'happened',
#   'pair',
#   'crocs',
#   'since',
#   'strap',
#   'moved',
#   'forward',
#   'look',
#   'like',
#   'trim',
#   'front',
#   'pleasantly',
#   'surprised',
#   'crocs',
#   'cushiony',
#   'soft',
#   'like',
#   'walking',
#   'also',
#   'material',
#   'insulating',
#   'enough',
#   'keep',
#   'foot',
#   'warm',
#   'air',
#   'hole',
#   'ventilate',
#   'enough',
#   'foot',
#   'sweaty',
#   'either'],
#  ['they',
#   'exactly',
#   'hoping',
#   'would',
#   'love',
#   'contoured',
#   'front',
#   'pouch',
#   'web',
#   'site',
#   'saw',
#   'read',
#   'said',
#   'want',
#   'order',
#   'size',
#   'larger',
#   'normal',
#   'would',
#   'agree',
#   'unless',
#   'want',
#   'snug',
#   'my',
#   'wife',
#   'love',
#   'well',
#   'quite',
#   'pleased',
#   'look',
#   'feel',
#   'ordered',
#   'different',
#   'pair',
#   'unico',
#   'good',
#   'quality',
#   'look',
#   'feel',
#   'great'],
#  ['these',
#   'basically',
#   'plain',
#   'black',
#   'yoga',
#   'pant',
#   'fine',
#   'good',
#   'quality',
#   'washed',
#   'fine',
#   'without',
#   'shrinking',
#   'hard',
#   'rhapsodise',
#   'adequate'],
#  ['teen',
#   'alternative',
#   'bathrobe',
#   'love',
#   'nice',
#   'warm',
#   'pretty',
#   'pink',
#   'color',
#   'they',
#   'small',
#   'usually',
#   'take',
#   'medium',
#   'large',
#   'could',
#   'used',
#   'sleeves',
#   'short',
#   'like',
#   'look',
#   'front'],
#  ['trying',
#   'find',
#   'heeled',
#   'sandal',
#   'back',
#   'strap',
#   'thing',
#   'excited',
#   'find',
#   'bought',
#   'pair',
#   'silver',
#   'bronze',
#   'black',
#   'turquoise',
#   'they',
#   'beautiful',
#   'comfortable',
#   'walked',
#   'around',
#   'disneyland',
#   'turquoise',
#   '9am',
#   'midnight',
#   'sizing',
#   'true',
#   'standard',
#   'shipping',
#   'fast',
#   'i',
#   'highly',
#   'recommend',
#   'sandal',
#   'amazon'],
#  ['great',
#   'grip',
#   'cool',
#   'rugged',
#   'look',
#   'comfortable',
#   'enough',
#   'regular',
#   'winter',
#   'well',
#   '80',
#   'got',
#   'though',
#   'might',
#   'best',
#   'option',
#   'around'],
#  ['nice',
#   'case',
#   'looking',
#   'something',
#   'compact',
#   'kodak',
#   'easy',
#   'share',
#   'digital',
#   'camera',
#   'perfect',
#   'inside',
#   'case',
#   'nice',
#   'size',
#   'front',
#   'pouch',
#   'side',
#   'pouch',
#   'easy',
#   'storage'],
#  ['love', 'pant', 'first', 'time', 'boarder', 'cold', 'deffinately', 'great'],
#  ['purchased',
#   'take',
#   'tour',
#   'greece',
#   'pretty',
#   'happy',
#   'loved',
#   'size',
#   'small',
#   'also',
#   'flatness',
#   'lightweight',
#   'compartements',
#   'easily',
#   'accessible',
#   'problem',
#   'wear',
#   'intended',
#   'accross',
#   'body',
#   'strap',
#   'tends',
#   'neck',
#   'keep',
#   'adjusting',
#   'every',
#   'five',
#   'minute',
#   'overall',
#   'pretty',
#   'good',
#   'though'],
#  ['great', 'measured', 'put', 'lost', 'inch', 'highly', 'recommend'],
#  ['father', 'love', 'great', 'coverage', 'easy'],
#  ['shawl',
#   'beauiful',
#   'right',
#   'color',
#   'excellent',
#   'value',
#   'good',
#   'product',
#   'fast',
#   'shippin'],
#  ['fatigue',
#   'wanted',
#   'thing',
#   'wrong',
#   'inseam',
#   'available',
#   'order',
#   'guess',
#   'fatigue',
#   'suppose',
#   'drawstring',
#   'bottom',
#   'son',
#   'want',
#   'hem',
#   'four',
#   'inch',
#   'other',
#   'excellent',
#   'product'],
#  ['hesitantly',
#   'ordered',
#   'first',
#   'pair',
#   'folk',
#   'readers',
#   'i',
#   'back',
#   'second',
#   'pair',
#   'they',
#   'comfortable',
#   'unique',
#   'well',
#   'crafted',
#   'the',
#   'company',
#   'offers',
#   'excellent',
#   'service',
#   'a',
#   'winner'],
#  ['complaints',
#   'everything',
#   'smoothly',
#   'recommend',
#   'seller',
#   'product',
#   'everyone',
#   'they',
#   'absolutely',
#   'great',
#   'exactly',
#   'described'],
#  ['love',
#   'sandal',
#   'although',
#   'lightweight',
#   'vastly',
#   'substantial',
#   'supportive',
#   'comfortable',
#   'flip',
#   'flop',
#   'may',
#   'another',
#   'pair',
#   'half',
#   'size'],
#  ['started',
#   'water',
#   'walking',
#   'fitness',
#   'center',
#   'pool',
#   'found',
#   'slipping',
#   'enough',
#   'bother',
#   'shoe',
#   'like',
#   'glove',
#   'inexpensive',
#   'would',
#   'recommend',
#   'anyone',
#   'desiring',
#   'purpose',
#   'water',
#   'related',
#   'activity',
#   'i',
#   'certain',
#   'would',
#   'great',
#   'beach'],
#  ['ordered',
#   'item',
#   'pair',
#   'mocha',
#   'nubuck',
#   'well',
#   'wearing',
#   'birks',
#   'various',
#   'variety',
#   'year',
#   'always',
#   'satisfied',
#   'delivery',
#   'time',
#   'customer',
#   'service',
#   'receive',
#   'midwest',
#   'sports',
#   'wear',
#   'clog',
#   'sort',
#   'weather',
#   'except',
#   'fresh',
#   'snow',
#   'soon',
#   'walkway',
#   'street',
#   'clear',
#   'back',
#   'thicker',
#   'sock',
#   'course'],
#  ['great',
#   'shoe',
#   'impressed',
#   'softeness',
#   'leather',
#   'immediate',
#   'comfort',
#   'versatility',
#   'shoe',
#   'definitely',
#   'well',
#   'made',
#   'year',
#   'round',
#   'slide',
#   'looking',
#   'classic',
#   'loafer',
#   'shoe'],
#  ['great', 'quality', 'notch', 'price', 'also', 'great'],
#  ['give',
#   'star',
#   'easy',
#   'spirit',
#   'sandle',
#   'ordered',
#   'like',
#   'delivery',
#   'fast',
#   'order',
#   'something',
#   'else'],
#  ['bought',
#   'boyfriend',
#   'soft',
#   'comfy',
#   'definitely',
#   'comfy',
#   'snuggle',
#   'bonus',
#   'like',
#   'complaint',
#   'sleeve',
#   'little',
#   'long',
#   'overall',
#   'happy',
#   'purchase'],
#  ['exactly',
#   'looking',
#   'longer',
#   'perfect',
#   'wearing',
#   'feels',
#   'nice',
#   'soft',
#   'belt',
#   'stiff'],
#  ['shoe', 'comfortable', 'easy', 'wear', 'feel', 'great', 'without', 'sock'],
#  ['purchased',
#   'sock',
#   'large',
#   'department',
#   'store',
#   'chicago',
#   'fell',
#   'love',
#   'wanted',
#   'rid',
#   'every',
#   'pair',
#   'trouser',
#   'sock',
#   'it',
#   'took',
#   'month',
#   'online',
#   'searching',
#   'major',
#   'department',
#   'store',
#   'find',
#   'last',
#   'resort',
#   'went',
#   'amazon',
#   'found',
#   'second',
#   'already',
#   'bought',
#   'pair',
#   'probably',
#   'order',
#   'another',
#   'dozen',
#   'rid',
#   'poorly',
#   'made',
#   'uncomfortable',
#   'sock',
#   'drawer',
#   'hooked',
#   'plus',
#   'size',
#   'easy',
#   'amazon'],
#  ['great',
#   'swimsuit',
#   'shape',
#   'since',
#   'showing',
#   'think',
#   'would',
#   'rate',
#   'lined',
#   'like',
#   'previous',
#   'speedos'],
#  ['size',
#   '2',
#   'ordered',
#   'size',
#   'small',
#   'ordered',
#   'another',
#   'pair',
#   'would',
#   'probably',
#   'medium',
#   'dryer',
#   'shrinkage',
#   'they',
#   'every',
#   'revealing',
#   'barely',
#   'comfortable',
#   'going',
#   'outside'],
#  ['ideal',
#   'wearing',
#   'layer',
#   'clothing',
#   'dressed',
#   'short',
#   'sleeve',
#   'however',
#   'personally',
#   'prefer',
#   'long',
#   'sleeved',
#   'version',
#   'company'],
#  ['these',
#   'shoe',
#   'awesome',
#   'bowled',
#   'past',
#   'couple',
#   'week',
#   'looking',
#   'color',
#   'everyone',
#   'league',
#   'noticed',
#   'said',
#   'positive',
#   'thing',
#   'thanks',
#   'super',
#   'fast',
#   'shipping',
#   'supurb',
#   'quailty'],
#  ['sock', 'nice', 'cost', 'much', 'price', 'little', 'unreasonable'],
#  ['every',
#   'time',
#   'wear',
#   'always',
#   'strike',
#   'good',
#   'conversation',
#   'thing',
#   'cartoon',
#   'cartoon',
#   'also',
#   'working',
#   'place',
#   'kid',
#   'tend',
#   'ease',
#   'i',
#   '3',
#   'year',
#   'high',
#   'quality',
#   'stain',
#   'really',
#   'easy',
#   'least',
#   'great',
#   'quality',
#   'only',
#   'downfall',
#   'little',
#   'dated',
#   'cent',
#   'stamp',
#   'kids',
#   'notice',
#   'neither',
#   'adult',
#   'worth',
#   'picking',
#   'great',
#   'price'],
#  ['tried', 'never', 'wear', 'boxer'],
#  ['wore',
#   'shoe',
#   'worked',
#   'foot',
#   'really',
#   'helped',
#   'pain',
#   'foot',
#   'ankle',
#   'knee',
#   'could',
#   'really',
#   'feel',
#   'difference',
#   'work',
#   'shoe',
#   'teeth',
#   'shoe',
#   'foot',
#   'really',
#   'felt',
#   'good',
#   'being',
#   'diabetic',
#   'concerned',
#   'circulation',
#   'i',
#   'believe',
#   'good',
#   'purchase',
#   'little',
#   'expensive',
#   'well',
#   'worth',
#   'i',
#   'plan',
#   'buying'],
#  ['standard',
#   'style',
#   'line',
#   'performance',
#   'jock',
#   'bike',
#   'waistband',
#   'slightly',
#   'smaller',
#   'traditional',
#   'inch',
#   'comfortable',
#   'pouch',
#   'nice',
#   'snug',
#   'giving',
#   'perfect',
#   'support',
#   'strap',
#   'twist',
#   'bind',
#   'easy',
#   'launder',
#   'pretty',
#   'inexpensive',
#   'got',
#   'old',
#   'worn',
#   'jock',
#   'bought',
#   'one',
#   'they',
#   'masculine',
#   'modern',
#   'comfortable',
#   'something',
#   'would',
#   'embarassing',
#   'putting',
#   'taking',
#   'like',
#   'orange',
#   'blue',
#   'jock',
#   'good',
#   'comes',
#   'black',
#   'version',
#   'also',
#   'great',
#   'worn',
#   'working',
#   'around',
#   'town',
#   'good'],
#  ['comfortable',
#   'actually',
#   'forget',
#   'wearing',
#   'like',
#   'worn',
#   'every',
#   'thong',
#   'huge',
#   'thinking',
#   'stop',
#   'wearing',
#   'thong',
#   'found',
#   'washed',
#   'pair',
#   'couple',
#   'time',
#   'regular',
#   'cycle',
#   'dried',
#   'still',
#   'holding',
#   'well',
#   'back',
#   'amazon',
#   'buy',
#   'girl',
#   'regret',
#   'sexy',
#   'comfy',
#   'could'],
#  ['bought',
#   'replace',
#   'identical',
#   'pair',
#   'wearing',
#   'year',
#   'got',
#   'one',
#   'london',
#   'made',
#   'england',
#   'new',
#   'pair',
#   'made',
#   'china',
#   'they',
#   'changed',
#   'good',
#   'there',
#   'room',
#   'like',
#   'however',
#   'heel',
#   'ill',
#   'fitted',
#   'loose',
#   'trim',
#   'stick',
#   'back',
#   'super',
#   'glue',
#   'starting',
#   'really',
#   'break',
#   'think',
#   'love',
#   'year',
#   'come',
#   'they',
#   'provide',
#   'good',
#   'ankle',
#   'support',
#   'keep',
#   'foot',
#   'warm',
#   'buyer',
#   'beware',
#   'boot',
#   'come',
#   'stiff',
#   'take',
#   'time',
#   'break',
#   'when',
#   'first',
#   'wear',
#   'around',
#   'house',
#   'occasionally',
#   'i',
#   'actually',
#   'wear',
#   'if',
#   'wear',
#   'long',
#   'first',
#   'definitely',
#   'wear',
#   'blister',
#   'foot',
#   'break',
#   'slowly',
#   'wonderfully',
#   'comfortable',
#   'pair',
#   'boot',
#   'last',
#   'long',
#   'time'],
#  ['robe',
#   'arrive',
#   'great',
#   'condition',
#   'timely',
#   'manner',
#   'boyfriend',
#   'absolutely',
#   'loved',
#   'christmas',
#   'gift',
#   'thanks'],
#  ['after',
#   'purchased',
#   'sport',
#   'case',
#   'creative',
#   'vision',
#   'read',
#   'horror',
#   'story',
#   'horror',
#   'story',
#   'case',
#   'tight',
#   'scratching',
#   'unit',
#   'even',
#   'leaving',
#   'sticky',
#   'residue',
#   'valuable',
#   'player',
#   'looked',
#   'around',
#   'going',
#   'package',
#   'deal',
#   'happy',
#   'i',
#   'took',
#   'time'],
#  ['wand',
#   'sturdy',
#   'full',
#   'sized',
#   'nicely',
#   'designed',
#   'even',
#   'made',
#   'plastic',
#   'kid',
#   'wanted',
#   'wand',
#   'could',
#   'play',
#   'harry',
#   'potter',
#   'much',
#   'appropriate',
#   'beautiful',
#   'fragile',
#   'expensive',
#   'collector',
#   'version',
#   'available'],
#  ['slightly', 'small', 'stiff'],
#  ['pretty',
#   'picky',
#   'come',
#   'certain',
#   'thing',
#   'life',
#   'item',
#   'happens',
#   'backpacks',
#   'spent',
#   'month',
#   'searching',
#   'one',
#   'finally',
#   'came',
#   'across',
#   'particular',
#   'model',
#   'start',
#   'saying',
#   'love',
#   'damn',
#   'thing',
#   'plenty',
#   'space',
#   'whole',
#   'bunch',
#   'extra',
#   'cord',
#   'suppose',
#   'hiker',
#   'would',
#   'think',
#   'look',
#   'nice',
#   'durable',
#   'must',
#   'since',
#   'everything',
#   'i',
#   'take',
#   'beating',
#   'i',
#   'telling',
#   'straight',
#   'horse',
#   'mouth',
#   'backpack',
#   'worth',
#   'money',
#   'came',
#   'slot'],
#  ['love', 'shoe', 'searching', 'right', 'ballet'],
#  ['beware',
#   'will',
#   'increase',
#   'appearance',
#   'breast',
#   'full',
#   'size',
#   'draw',
#   'back',
#   'acquiring',
#   'bra',
#   'slyly',
#   'wearing',
#   'without',
#   'family',
#   'worker',
#   'knowing',
#   'something'],
#  ['bought',
#   'model',
#   'discount',
#   'store',
#   'lucky',
#   'quickly',
#   'became',
#   'favorite',
#   'glad',
#   'find',
#   'amazon'],
#  ['very',
#   'nice',
#   'basic',
#   'clothing',
#   'think',
#   'size',
#   'fine',
#   'really',
#   'like',
#   'able',
#   'find',
#   'shade',
#   'green',
#   'though',
#   'decided',
#   'lighter',
#   'shade',
#   'really',
#   'feminine',
#   'color',
#   'brand',
#   'find',
#   'muted',
#   'green'],
#  ['bought',
#   'boot',
#   'time',
#   'crazy',
#   'weather',
#   'started',
#   'tell',
#   'boot',
#   'great',
#   'read',
#   'review',
#   'bought',
#   'half',
#   'size',
#   'bigger',
#   'little',
#   'regardless',
#   'love',
#   'another',
#   'thing',
#   'keep',
#   'foot',
#   'warm',
#   'cozy'],
#  ['got',
#   'sock',
#   'gift',
#   'baby',
#   'shower',
#   'looked',
#   'everywhere',
#   'trying',
#   'find',
#   'could',
#   'these',
#   'sock',
#   'stay',
#   'little',
#   'foot',
#   'made',
#   'well'],
#  ['husband',
#   'man',
#   'rough',
#   'belt',
#   'most',
#   'belt',
#   'last',
#   'week',
#   'one',
#   'lasted',
#   'year',
#   'reason',
#   'buying',
#   'one',
#   'lost',
#   'much',
#   'weight',
#   'there',
#   'still',
#   'mile',
#   'left',
#   'belt',
#   'replacing',
#   'definitely',
#   'money',
#   'worth'],
#  ...]

# %%
#All Words
from nltk import FreqDist
def Bag_Of_Words(ListWords):
    all_words = []
    for m in ListWords:
        for w in m:
            all_words.append(w.lower())
    all_words = FreqDist(all_words)
    #print(all_words.most_common(300))
    #print(len(all_words.keys()))
    return all_words

# %%
all_words = Bag_Of_Words(ListWords)

# %%
all_words
# Out:
# FreqDist({'trust': 159,
#           'pixel': 27,
#           'jonny': 1,
#           'grungifying': 1,
#           'ranch': 9,
#           'hoped': 101,
#           'yali': 2,
#           'imagery': 16,
#           'blending': 13,
#           'bearly': 3,
#           'purcased': 1,
#           'relative': 70,
#           'wiped': 16,
#           'backbeat': 3,
#           'moja': 2,
#           'nashville': 12,
#           'maximumpc': 4,
#           'seller': 200,
#           'architectural': 10,
#           'suspenseful': 22,
#           'krooked': 1,
#           'shortest': 3,
#           'faintly': 2,
#           'concentrate': 26,
#           'elaine': 5,
#           'pontificating': 2,
#           'tailbone': 3,
#           'tooooo': 3,
#           'ersatz': 2,
#           'iffy': 6,
#           'striker': 3,
#           'snakcs': 1,
#           'roundup': 1,
#           'macpherson': 2,
#           'warren': 27,
#           'tomatoes': 4,
#           'fuse': 20,
#           'bejeezus': 1,
#           '45mm': 1,
#           'clarifiance': 1,
#           'reallity': 2,
#           'exquisite': 11,
#           'janssen': 3,
#           'hott': 1,
#           'faulty': 36,
#           'maneuverabiltity': 2,
#           'claud': 1,
#           'brunt': 1,
#           'illustration': 40,
#           'drys': 1,
#           'cherry': 71,
#           'altima': 1,
#           'brightening': 3,
#           'obstructing': 1,
#           'cheek': 30,
#           'dope': 18,
#           'vaccuum': 1,
#           '2255': 1,
#           'murra': 1,
#           'otto': 3,
#           'holidday': 3,
#           'shoulda': 2,
#           'conducive': 5,
#           'hatch': 5,
#           'confessed': 2,
#           'impersonal': 1,
#           'baptism': 2,
#           'advert': 7,
#           'overwhelms': 1,
#           'berk': 1,
#           'humperdinck': 1,
#           'knight': 13,
#           'maneuverable': 2,
#           'marley': 4,
#           'bandmates': 1,
#           'tail': 44,
#           'rotisserie': 28,
#           'softwate': 1,
#           'thusfar': 2,
#           'richard': 66,
#           'hermann': 1,
#           'afficionado': 3,
#           'zaks': 1,
#           'stonge': 2,
#           '70oz': 1,
#           'climber': 7,
#           'local': 430,
#           'bucks': 5,
#           '749mm': 1,
#           'regard': 49,
#           'winne': 1,
#           'imagine': 247,
#           'adkins': 1,
#           'legacy': 29,
#           'pale': 29,
#           'fassbinder': 1,
#           'simmilar': 1,
#           'neocon': 6,
#           'pulsating': 1,
#           'alfredo': 8,
#           'peavy': 1,
#           'improvise': 3,
#           'doesnot': 3,
#           'grating': 10,
#           'aeneid': 1,
#           'paulsen': 2,
#           'chop': 22,
#           'sierras': 1,
#           'dock': 45,
#           'showboat': 1,
#           'reoccurring': 2,
#           'imposes': 1,
#           'instalación': 1,
#           'chese': 1,
#           'shakspeare': 1,
#           'temomitor': 1,
#           'shearling': 4,
#           'rogue': 2,
#           'shininess': 1,
#           'na': 1,
#           'emotionally': 31,
#           'embarrases': 1,
#           'derails': 1,
#           'flashlights': 1,
#           'fantastic1': 1,
#           'unattrctive': 1,
#           'spliting': 1,
#           'bathroom': 99,
#           'preform': 1,
#           'duma': 1,
#           'section': 246,
#           'corporatly': 1,
#           'articulates': 1,
#           'conair': 28,
#           'interview': 132,
#           'cases': 1,
#           'mcgegan': 1,
#           'shaped': 51,
#           'grip': 153,
#           'directed': 94,
#           'grooming': 9,
#           'retrieve': 11,
#           'streep': 7,
#           'wooten': 1,
#           'victorian': 5,
#           'totted': 1,
#           'savor': 12,
#           'scurried': 1,
#           'passion': 64,
#           'tenenbaums': 4,
#           'format': 165,
#           'easil': 1,
#           'shot': 432,
#           'impassioned': 1,
#           'carradine': 4,
#           'amparado': 2,
#           'rendition': 25,
#           'melodiousness': 1,
#           'tubb': 1,
#           'sofia': 5,
#           'adverturous': 1,
#           'unwated': 1,
#           'karts': 1,
#           'probubly': 1,
#           'richards': 7,
#           'jodhpur': 1,
#           'highlight': 65,
#           'bahjerba': 1,
#           'blip': 2,
#           '8256u': 2,
#           'cote': 1,
#           'louds': 1,
#           'puedes': 1,
#           'filmsy': 2,
#           'collectables': 1,
#           'wasting': 64,
#           'colin': 13,
#           'kanoka': 1,
#           'befriends': 3,
#           'downpour': 5,
#           'gyokuro': 1,
#           'manuracturer': 1,
#           'z500': 1,
#           'qulity': 1,
#           'prefection': 1,
#           '180lbs': 2,
#           'carried': 55,
#           'datapilot': 3,
#           'contested': 1,
#           'geogaddi': 1,
#           'bandwith': 1,
#           'sunbelt': 1,
#           'megadeth': 3,
#           '60gb': 9,
#           'geranium': 1,
#           'disproved': 1,
#           'homedics': 4,
#           'touch': 323,
#           'partake': 2,
#           '3hours': 1,
#           'passing': 28,
#           'whipped': 13,
#           'brightest': 5,
#           'accelerated': 6,
#           'perfomance': 5,
#           'microscams': 2,
#           'resist': 42,
#           'humectant': 3,
#           'screenshots': 3,
#           'effort': 216,
#           'tame': 16,
#           'reasonably': 67,
#           'nonni': 1,
#           'bowled': 3,
#           'harp': 12,
#           'manning': 2,
#           'rethought': 2,
#           'dispicable': 1,
#           'anbd': 1,
#           'stupefying': 2,
#           'pequeninos': 1,
#           'ight': 1,
#           'smelled': 96,
#           'greetings': 6,
#           'amazoned': 1,
#           'palmone': 1,
#           'nanometer': 1,
#           'telepathy': 1,
#           'themself': 2,
#           'cookbook': 34,
#           'experiment': 30,
#           'i0l0': 1,
#           'upwords': 1,
#           'snipes': 2,
#           'atrevido': 1,
#           'encuentro': 2,
#           'endou': 1,
#           'mental': 39,
#           'carroll': 6,
#           'pharell': 1,
#           'mellowed': 2,
#           'boton': 1,
#           'qaida': 1,
#           'siging': 1,
#           'respondind': 2,
#           'misreads': 1,
#           'festival': 10,
#           'between': 17,
#           'abril': 1,
#           'bulworth': 1,
#           'dimming': 2,
#           'wound': 32,
#           'gorehounds': 2,
#           'carefully': 86,
#           'parred': 1,
#           'carees': 1,
#           'hutton': 1,
#           'shpping': 2,
#           'rankin': 3,
#           'spirulina': 10,
#           'hottie': 2,
#           'inaugural': 3,
#           'forking': 4,
#           'cheers': 2,
#           'onenote': 12,
#           'utne': 1,
#           'aromatheropy': 1,
#           'murad': 34,
#           'prohibitive': 3,
#           'neurologist': 2,
#           'lactic': 2,
#           'data': 174,
#           'milhouse': 1,
#           'philippa': 3,
#           'powerwashing': 1,
#           'unsecured': 1,
#           'rugby': 1,
#           'calorie': 124,
#           'meandering': 5,
#           'mints': 2,
#           '1973': 12,
#           'deliciously': 8,
#           'submerged': 7,
#           'plath': 1,
#           'retrospective': 5,
#           'ekco': 1,
#           'propmpt': 1,
#           'smaller': 349,
#           'blot': 4,
#           'tram': 1,
#           'thermosat': 2,
#           'coolpix': 25,
#           'tales': 9,
#           'prequil': 2,
#           'averse': 1,
#           'passionatly': 1,
#           'aria': 16,
#           'avert': 1,
#           'bossa': 1,
#           'cruises': 2,
#           'dridget': 2,
#           'kiding': 1,
#           'juiceless': 3,
#           'caravan': 2,
#           'chato': 1,
#           'convicing': 1,
#           'restrained': 1,
#           'andy': 18,
#           'stewing': 3,
#           'gfts': 1,
#           'v570': 2,
#           'spun': 6,
#           'appropriated': 1,
#           'victum': 1,
#           'stinky': 14,
#           'lindt': 5,
#           'goog': 1,
#           'fondue': 5,
#           '0000': 1,
#           'drudgery': 2,
#           'inwhere': 2,
#           'sweetie': 3,
#           'swaddling': 15,
#           'blaster': 12,
#           'fredkin': 4,
#           'bulleted': 1,
#           'dawson': 5,
#           'bypassed': 1,
#           'cooper': 12,
#           'memorize': 5,
#           'beside': 13,
#           'acually': 1,
#           '20x30': 1,
#           'omission': 5,
#           'tommorrow': 1,
#           'context': 38,
#           'solder': 4,
#           'graco': 54,
#           'bleeding': 15,
#           'victoria': 19,
#           'thrice': 2,
#           'academia': 4,
#           'conditionner': 1,
#           'agaist': 1,
#           'regulars': 1,
#           'dogville': 1,
#           'sweeth': 1,
#           'sakabatos': 1,
#           'w100': 2,
#           'alike': 33,
#           'nightlight': 6,
#           'fleur': 3,
#           'represented': 20,
#           'hillbilly': 5,
#           'realtions': 1,
#           'fujian': 1,
#           'guyton': 1,
#           'lenovo': 2,
#           'celular': 2,
#           'frenzy': 8,
#           'kaffir': 1,
#           'merlin': 2,
#           'disipointed': 1,
#           'tarantino': 5,
#           'banned': 6,
#           'clod': 4,
#           'encryted': 1,
#           '30cpkxs': 1,
#           'postcard': 5,
#           'ocasiones': 1,
#           'upholstery': 4,
#           'emptied': 6,
#           'independence': 12,
#           'portends': 1,
#           'orgasmic': 2,
#           'celtic': 12,
#           'waisted': 3,
#           'overtly': 2,
#           'heilman': 3,
#           'dashed': 4,
#           'wallah': 1,
#           'seperating': 2,
#           '20db': 1,
#           'waiting': 278,
#           'closeup': 2,
#           'diagnose': 5,
#           'kitschy': 1,
#           'beatyfull': 1,
#           'pans': 1,
#           'glittery': 4,
#           'cateye': 8,
#           'imago': 3,
#           'discerning': 5,
#           'sixty': 23,
#           'prostitute': 13,
#           'contemplative': 1,
#           'unexciting': 3,
#           'aura': 1,
#           'deffinately': 2,
#           'silkscreened': 2,
#           'brooklyn': 5,
#           'cushiony': 7,
#           'anniversaty': 1,
#           'consulted': 2,
#           'gladly': 20,
#           'folica': 1,
#           'dictionary': 43,
#           'surpasses': 5,
#           'enthusiasm': 22,
#           'qualxserv': 1,
#           'godlovesugly': 1,
#           'ingesting': 3,
#           'newver': 1,
#           'hillside': 2,
#           'stability': 29,
#           'outgrown': 9,
#           'nemesis': 7,
#           'unconventional': 5,
#           'till': 88,
#           'penagain': 4,
#           'impervious': 1,
#           'frayed': 8,
#           'teasp': 1,
#           'marketed': 20,
#           'bar898hga': 1,
#           '640x480': 2,
#           'cornsticks': 1,
#           'pork': 29,
#           'seltzer': 1,
#           'corner': 119,
#           'vtech': 4,
#           'marginalized': 2,
#           'abroad': 11,
#           'overdubbing': 1,
#           'fresher': 4,
#           'krackers': 3,
#           'beige': 19,
#           'germaine': 1,
#           'imagined': 17,
#           'deodorant': 16,
#           'zorbitt': 2,
#           'd70s': 8,
#           'mcgaughlin': 1,
#           'justin': 8,
#           'implausibility': 1,
#           'leering': 2,
#           'nicholson': 14,
#           'taut': 6,
#           'origianl': 1,
#           'veture': 1,
#           'walreens': 1,
#           'ashen': 1,
#           'strobe': 6,
#           'manners': 2,
#           'aquolina': 1,
#           'nukes': 1,
#           'blighted': 1,
#           'indanger': 1,
#           '15min': 1,
#           'minents': 1,
#           'skipdoctor': 1,
#           'funner': 2,
#           'ridgely': 1,
#           'hubby': 17,
#           'napoleonic': 2,
#           'mesmerizingly': 1,
#           'insistance': 1,
#           'sonagram': 1,
#           'maintanence': 2,
#           'disposal': 9,
#           'bundle': 57,
#           'murrills': 1,
#           'babys': 1,
#           'safari': 16,
#           'agravating': 1,
#           'nurser': 10,
#           'texans': 1,
#           'polish': 48,
#           'heartstrings': 3,
#           'bonham': 2,
#           'bessie': 2,
#           'annotation': 4,
#           'split': 91,
#           'hewlett': 3,
#           'murdoch': 5,
#           'dealer': 32,
#           '7ghz': 1,
#           'ssid': 1,
#           'pots': 1,
#           'shoes': 15,
#           'spookie': 1,
#           'hide': 57,
#           'bonomo': 1,
#           'spelling': 14,
#           'adress': 2,
#           'eceg': 1,
#           'tecra': 1,
#           'havng': 1,
#           'sandlin': 1,
#           'bachlor': 1,
#           'downer': 3,
#           'informaiton': 2,
#           'hips': 2,
#           'disneymania': 1,
#           'brighty': 1,
#           'interferance': 1,
#           'kersey': 1,
#           'grandson': 106,
#           'westinghouse': 1,
#           'fryer': 20,
#           'stero': 1,
#           'stringley': 1,
#           'bidding': 3,
#           'reefers': 1,
#           'bruder': 1,
#           'bidder': 1,
#           'n_____': 1,
#           'clog': 23,
#           'coupled': 11,
#           'ranking': 10,
#           'bestowed': 2,
#           'postwar': 1,
#           'deleted': 21,
#           'offense': 6,
#           'cubic': 5,
#           'chapman': 4,
#           'scoobas': 1,
#           'designed': 279,
#           'refer': 46,
#           'nashbar': 2,
#           'acuricy': 1,
#           'gere': 11,
#           'cooks': 11,
#           'bikini': 22,
#           '6500': 1,
#           'stitch': 23,
#           'straining': 5,
#           'saya': 1,
#           'artisanal': 1,
#           'solar': 40,
#           'farrel': 1,
#           'aunty': 1,
#           'coney': 2,
#           'vernor': 1,
#           'pimpernel': 1,
#           'denzel': 11,
#           'snowsuit': 5,
#           'ache': 15,
#           'unsentimental': 1,
#           'luring': 1,
#           'diffident': 1,
#           'repeat': 88,
#           'pyramyd': 1,
#           'satelite': 1,
#           'primo': 3,
#           'ulead': 4,
#           'publishes': 4,
#           'untucked': 1,
#           'jaci': 7,
#           'uncut': 9,
#           'consecutive': 6,
#           'niven': 3,
#           'conection': 5,
#           'backend': 1,
#           'coherently': 1,
#           'daytripping': 1,
#           'electronic': 72,
#           'fellings': 1,
#           'intuos3': 1,
#           'flyer': 18,
#           'illustrade': 1,
#           'shild': 1,
#           'intrisically': 1,
#           'happens': 171,
#           'unergonomic': 1,
#           'killed': 73,
#           'arranged': 16,
#           'proven': 33,
#           'depressing': 39,
#           'droplet': 1,
#           'antiseptic': 2,
#           'chipmunk': 1,
#           'apratmant': 1,
#           'maverick': 7,
#           'disenfranchise': 1,
#           'grest': 1,
#           'ambiguity': 3,
#           'lusting': 1,
#           'mobile': 114,
#           'moodiness': 1,
#           'hazard': 28,
#           'jenseits': 2,
#           'plum': 6,
#           'rapida': 2,
#           'behemouth': 1,
#           'bryant': 2,
#           'imbibe': 1,
#           'commemorates': 1,
#           'haskin': 1,
#           'mystere': 1,
#           'prosaic': 1,
#           '1965': 7,
#           's500': 10,
#           'tg5571': 1,
#           'memorable': 49,
#           'shayne': 1,
#           'filmic': 1,
#           'christams': 3,
#           'waist': 81,
#           'damabe': 1,
#           'wrong': 734,
#           'wylde': 1,
#           'galleries': 1,
#           'molotov': 1,
#           'exceptable': 1,
#           'leech': 5,
#           'fiberglass': 1,
#           'wmr968': 1,
#           'csla': 1,
#           'goining': 1,
#           'mothering': 1,
#           'linguistics': 1,
#           'scoring': 17,
#           'megpixels': 1,
#           'conscience': 11,
#           'tuner': 62,
#           'supurb': 2,
#           'jlpt3': 1,
#           'gawd': 3,
#           'ficticious': 1,
#           'sauna': 4,
#           'evenflow': 2,
#           'dropped': 191,
#           'improv': 3,
#           '1943': 3,
#           'reissued': 4,
#           'sparsely': 2,
#           'dollar': 369,
#           'cram': 2,
#           'compaired': 6,
#           'jeckyl': 1,
#           'modus': 2,
#           'paranoia': 5,
#           'capone': 2,
#           'competing': 17,
#           'alfalfa': 1,
#           'indigenous': 1,
#           'brockovich': 1,
#           'swept': 5,
#           'kane': 7,
#           'wiipoints': 2,
#           'coriscan': 2,
#           'grad': 13,
#           'room': 744,
#           'golfing': 2,
#           'oversung': 1,
#           'leona': 1,
#           'brickell': 1,
#           'sheath': 4,
#           'boitano': 2,
#           'warping': 6,
#           'troupe': 4,
#           'w710i': 2,
#           'stayin': 1,
#           'meet': 137,
#           'queda': 1,
#           'celts': 1,
#           'unpredictably': 2,
#           'crippled': 11,
#           'selena': 4,
#           'rumors': 2,
#           'zeppoles': 1,
#           'lengh': 1,
#           'hucksters': 1,
#           'ext3': 2,
#           'surpise': 2,
#           'windstop': 1,
#           'twelfth': 2,
#           'amounnt': 1,
#           'genuine': 43,
#           'blender': 45,
#           'netgear': 13,
#           'spellbinding': 1,
#           'argentinean': 1,
#           'tweezers': 3,
#           'subversive': 5,
#           'airedale': 1,
#           'insantity': 1,
#           'viatek': 3,
#           'gitcorp': 1,
#           'formadahyde': 1,
#           'mitochondrion': 1,
#           'bamba': 1,
#           'toppling': 1,
#           'eire': 1,
#           'officejet': 3,
#           '1900s': 1,
#           'egghead': 2,
#           'exellent': 1,
#           'funk': 28,
#           'guilio': 1,
#           'duster': 20,
#           'alec': 11,
#           'jail': 15,
#           'positioned': 10,
#           'nutrasweet': 1,
#           'antagonist': 3,
#           'antitrust': 1,
#           'atmospheric': 12,
#           'faye': 5,
#           'unfunny': 12,
#           'rabbit': 30,
#           'unclip': 1,
#           'dubus': 1,
#           'oneself': 3,
#           'gravy': 8,
#           'comeback': 4,
#           'cansiter': 1,
#           'eary': 1,
#           'disceaving': 1,
#           'infomercials': 1,
#           'seen': 901,
#           'claris': 2,
#           'playfully': 1,
#           'leftover': 17,
#           'delibitating': 1,
#           'stressing': 2,
#           'flavia': 1,
#           'massage': 58,
#           'vilver': 1,
#           'specialy': 1,
#           'sqooshed': 1,
#           'encourages': 15,
#           'cheeze': 4,
#           'djanglo': 4,
#           'predicament': 3,
#           'beastie': 5,
#           'homer': 4,
#           'stragety': 1,
#           'juggle': 2,
#           'franklin': 16,
#           'pioneering': 1,
#           'contractual': 1,
#           'peerless': 2,
#           'cosby': 2,
#           'emeralds': 1,
#           'wight': 2,
#           'smiths': 1,
#           'omni': 5,
#           'magnificantly': 1,
#           'crouching': 2,
#           'loudly': 14,
#           'sesame': 25,
#           'subtext': 1,
#           'warfare': 5,
#           'shem': 3,
#           'bores': 1,
#           'congealed': 3,
#           'childrens': 14,
#           'watch': 1900,
#           'es8162s': 1,
#           'moroso': 1,
#           'defective': 167,
#           'tiffen': 12,
#           'renturnd': 1,
#           'actron': 4,
#           'daycare': 15,
#           'whne': 1,
#           'turbulent': 1,
#           'podcasting': 1,
#           'rainier': 1,
#           'superglue': 4,
#           'association': 10,
#           'blustery': 1,
#           'bolder': 3,
#           'sally': 11,
#           'mulligan': 5,
#           'shriveled': 3,
#           'yipee': 1,
#           '1920': 4,
#           'occasionally': 90,
#           'roncal': 1,
#           'gunked': 3,
#           'dacanture': 1,
#           'versian': 1,
#           'mcdormand': 1,
#           'dissatisfaction': 3,
#           'angelica': 4,
#           'shaddow': 1,
#           'troubleshoot': 3,
#           'wander': 8,
#           'digger': 5,
#           'belgium': 3,
#           'dalliance': 1,
#           'k850': 2,
#           'frazzled': 1,
#           'intelegant': 1,
#           'airsplat': 15,
#           'lanky': 1,
#           'masterfully': 9,
#           'agravation': 1,
#           'derpression': 1,
#           'leatherette': 1,
#           'singapore': 6,
#           'flannery': 1,
#           'overcooked': 1,
#           'sledding': 1,
#           'classicist': 2,
#           'hornblower': 3,
#           'arbor': 2,
#           'stab': 12,
#           'animal': 162,
#           'governmental': 1,
#           'bendy': 5,
#           'overlooking': 1,
#           'gilmore': 2,
#           'lifter': 8,
#           'nordicware': 2,
#           'chowing': 1,
#           'fumbling': 3,
#           'leaned': 4,
#           'soldier': 48,
#           'karan': 2,
#           'deyoung': 1,
#           'dpf70': 1,
#           'padding': 70,
#           'aminal': 2,
#           'illest': 2,
#           'dalton': 3,
#           'motivate': 6,
#           'replcing': 1,
#           'mingling': 1,
#           'coffee': 747,
#           'jules': 4,
#           '1924': 2,
#           'schizzle': 1,
#           'neighboring': 1,
#           'restock': 2,
#           'ridiciulous': 1,
#           'threaders': 1,
#           'grootjans': 1,
#           'tura': 1,
#           'ironic': 16,
#           'hinky': 1,
#           'game': 3894,
#           'purist': 4,
#           'quaterback': 1,
#           'mettle': 1,
#           'practically': 78,
#           'gryl': 1,
#           'carves': 1,
#           'crule': 1,
#           'portis': 1,
#           'accumulate': 3,
#           'sharpest': 5,
#           'cand': 2,
#           'spinning': 26,
#           'faultless': 1,
#           'schaffer': 1,
#           '700mb': 1,
#           'keyword': 1,
#           'venda': 1,
#           'talla': 1,
#           'kraft': 4,
#           'overpower': 3,
#           'romans': 3,
#           'revolutinary': 1,
#           'linseed': 2,
#           'ponderous': 3,
#           'paving': 2,
#           'k800i': 1,
#           'exaggerates': 1,
#           'balked': 1,
#           'lifer': 2,
#           'hacked': 3,
#           'bambataa': 1,
#           'p880': 1,
#           '1050w': 1,
#           'publicist': 1,
#           'trueendorsement': 1,
#           'gic251u': 1,
#           'communicated': 4,
#           'storyteller': 7,
#           'pressfield': 2,
#           'oldfield': 1,
#           'sorr': 1,
#           'fromk': 1,
#           'understanding': 110,
#           'tribulation': 5,
#           'double': 219,
#           'cooley': 1,
#           'jarring': 5,
#           'qualty': 3,
#           'anemometer': 3,
#           'attack': 79,
#           'woulud': 1,
#           'berlitz': 1,
#           'protectthe': 1,
#           'removed': 98,
#           'plumping': 7,
#           'd70u': 1,
#           'nongshim': 3,
#           'dreaming': 8,
#           'radiance': 2,
#           'filmmaker': 33,
#           'precio': 1,
#           'bassist': 5,
#           'demolished': 2,
#           'glider': 2,
#           'issard': 1,
#           'putty': 1,
#           '12x4': 1,
#           'uncommunicative': 1,
#           'sprinkles': 2,
#           'flipp': 1,
#           'kombat': 8,
#           'replicator': 1,
#           'turtles': 3,
#           'icons': 2,
#           'investors': 1,
#           'herramientas': 2,
#           'raider': 3,
#           'veranda': 4,
#           '1977': 4,
#           'detoxification': 1,
#           'harpie': 2,
#           'tomadas': 1,
#           'classer': 1,
#           'regulating': 1,
#           'witt': 1,
#           'polk': 6,
#           'billion': 9,
#           'incoherently': 1,
#           'stomped': 3,
#           'reluctance': 5,
#           'horizonal': 1,
#           'sounded': 113,
#           'foggy': 3,
#           'domino': 6,
#           'outsided': 11,
#           'moisterized': 1,
#           'daft': 4,
#           'degrading': 2,
#           'unfairness': 1,
#           'unlined': 6,
#           'crossreferences': 1,
#           'perversity': 1,
#           'inport': 2,
#           'bikers': 4,
#           'capo': 7,
#           'downswing': 2,
#           'unload': 3,
#           'flips': 2,
#           'nerds': 1,
#           'logan': 4,
#           'raps': 2,
#           'poderoso': 1,
#           'orbach': 1,
#           'spanky': 1,
#           'basmati': 6,
#           'unlighted': 1,
#           'killer': 96,
#           'bushing': 1,
#           'mismatch': 1,
#           'borderline': 6,
#           'readjust': 9,
#           'fail': 82,
#           'talons': 1,
#           'unsuccessful': 9,
#           'challengingly': 2,
#           'smartdeck': 1,
#           'críptico': 1,
#           'wealthiest': 1,
#           'frolicking': 1,
#           'tamaño': 3,
#           'nymphomaniac': 1,
#           'irritation': 27,
#           'mcmurry': 1,
#           'benzon': 1,
#           'tunes': 1,
#           'strike': 43,
#           'snickered': 2,
#           'minds': 3,
#           'kosher': 6,
#           'sarcastically': 3,
#           'sawdust': 4,
#           '540ez': 1,
#           'competely': 1,
#           'lodge': 8,
#           'isnt': 67,
#           'dosage': 7,
#           'comfortably': 50,
#           'a640': 2,
#           'disposing': 2,
#           'inconveniently': 2,
#           'republicans': 4,
#           'yourcenar': 1,
#           'juuuuuuust': 1,
#           'imporartantly': 1,
#           'teakettle': 2,
#           ...})

# %%
import random
def Create_Document(ReviewsText,ListWords):
    ListClass = list(ReviewsText['Class'])
    Documents =  []
    for m in range(len(ListWords)):
        Documents.append((ListWords[m],ListClass[m]))
    #shuffle
    random.shuffle(Documents)
    return Documents
#on va utiliser Reviews Books
Documents = Create_Document(ReviewsText,ListWords)

# %%
print(Documents[1])
# Out:
# (['juicer', 'year', 'problem', 'fact', 'several', 'juicer', 'favorite', 'price', 'range'], 'pos')

# %% [markdown]
# #### Motivation: Why Word Embeddings?
#
# Image and audio processing systems work with rich, high-dimensional datasets encoded as vectors of the individual raw pixel-intensities for image data, or e.g. power spectral density coefficients for audio data. For tasks like object or speech recognition we know that all the information required to successfully perform the task is encoded in the data (because humans can perform these tasks from the raw data). However, natural language processing systems traditionally treat words as discrete atomic symbols, and therefore 'cat' may be represented as Id537 and 'dog' as Id143. These encodings are arbitrary, and provide no useful information to the system regarding the relationships that may exist between the individual symbols. This means that the model can leverage very little of what it has learned about 'cats' when it is processing data about 'dogs' (such that they are both animals, four-legged, pets, etc.). Representing words as unique, discrete ids furthermore leads to data sparsity, and usually means that we may need more data in order to successfully train statistical models. Using vector representations can overcome some of these obstacles.
# https://www.tensorflow.org/tutorials/word2vec
# #### How word2vec works:
#
# The idea behind word2vec is that:
#
#     Take a 3 layer neural network. (1 input layer + 1 hidden layer + 1 output layer)
#     Feed it a word and train it to predict its neighbouring word.
#     Remove the last (output layer) and keep the input and hidden layer.
#     Now, input a word from within the vocabulary. The output given at the hidden layer is the ‘word embedding’ of the input word.
# Two popular examples of methods of learning word embeddings from text include:
#
#     Word2Vec.
#     GloVe.
#
# In addition to these carefully designed methods, a word embedding can be learned as part of a deep learning model. This can be a slower approach, but tailors the model to a specific training dataset.

# %%
import gensim, logging
from gensim.models.word2vec import Word2Vec # the word2vec model gensim class
# Out:
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\gensim\utils.py:1167: UserWarning:
#
# detected Windows; aliasing chunkize to chunkize_serial

# %% [markdown]
# ### Load model

# %%
model = Word2Vec.load('model.bin')

# %%
words = list(model.wv.vocab)
print(words)
# Out:
# ['atlas', 'godfathers', 'artcle', 'frothiness', 'dresden', 'creation', 'smugglers', 'panda', 'dines', 'gees', 'rowing', 'crayon', 'fowarding', 'katy', '24mo', 'nationally', 'darrin', 'kanji', 'movie', 'fusion', 'straying', 'thse', 'seleccionar', 'exprerience', 'woodman', 'toeless', 'nebraska', 'samsung', 'reimbursed', 'circular', 'incorrect', 'bradbury', 'ziplock', 'sinead', 'braindead', 'obscurity', 'gusty', 'talentless', 'parading', 'innefficient', 'documenting', 'misreading', 'dice', 'pocketing', 'tecture', 'crankshaft', 'spantaneous', 'causing', 'durum', 'usual', 'innovating', 'render', 'porter', 'hive', 'janitor', 'staticy', 'saftey', 'gilster', 'likelier', 'gosta', 'caddylink', 'waranty', 'travelogue', 'diablo', 'tandam', 'den
 'techtoysforless', 'tablecloth', 'ppro', 'building', 'azumi', 'casa', 'treasury', 'compnay', 'bulkyness', 'reiner', 'videophone', 'plate', 'imax', 'armpit', 'adores', 'exert', 'alleviate', 'plotline', 'syd', 'clicky', 'batou', 'passionatly', 'kyle', 'analyzation', 'mcmahon', 'hoard', 'frishmann', 'espcomp', 'aswell', 'expresso', 'tonk', 'diapering', 'tundra', 'lyracist', 'bonnaroo', 'biggs', 'leech', 'scr ...

# %% [markdown]
# ### Train model

# %%
# train model
model = Word2Vec(ListWords, min_count=1)
# summarize the loaded model
print(model)
# summarize vocabulary
words = list(model.wv.vocab)
print(words)
# access vector for one word
print(model['good'])
# save model
model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# Word2Vec(vocab=47478, size=100, alpha=0.025)
# ['bounded', 'cmd', 'dï', 'abusive', 'already', 'mikasa', 'woolf', 'buena', 'parkland', 'gotta', 'pematurely', 'dec', 'implemented', 'rod', 'mmod', 'fred', 'okami', 'sequence', 'ok', 'mudslide', 'godspell', 'rerelease', 'registering', 'stylize', 'aux', 'hurley', 'runtime', 'gaving', 'signifies', 'banaster', 'bold', '1086', 'pixilation', 'rio', 'areally', 'compress', 'baumer', 'glazed', 'missles', 'shepp', 'abyss', 'workin', 'prometheus', 'seperated', 'backrgound', 'targeted', 'henna', 'camaera', 'firaxis', 'monopoly', 'fx100', 'recruiter', 'pilaff', 'strengthens', 'elgar', 'blush', 'tylenol', 'necessity', 'ofice', 'succumbing', 'beause', 'sleeves', 'fail', 'answere', 'improves', 'huge', 'andis', 'retin', 'programme', 'couplet', 'dandy', 'azam', 'protrusion', 'instructs', 'duct', 'otham', 'salad', 'technicality', 'obtained', 'jinpachi', 'encryted', 'excersize', 'piled', 'undead', 'moreso', 'bp522', 'spinner', 'someones', '3weeks', 'compatible', 'shying', 'alas', 'downloads', 'minimizer', 'tricetta', 'unfortantllly', 'gena', 'defensive', 'contibuted', '33185', 'tracks', 'gwyneth', 'frangrance', 'visist', 'overstressing', 'husbund', 'monica', 'stroller', 'shortstop', 'girl', 'duff', '5x', 'distress', 'tangible', 'fasd', 'textural', 'swiffer', 'abomination', 'edged', 'dechyper', 'transmitting', 'ladyshave', 'cf', 'perspicacious', 'takin', 'myslef', 'fenugreek', 'conditioner', 'touch', 'measured', 'lunacy', 'born', 'mixture', 'spat', 'tickle', 'europa', 'dehumidifer', 'n8008s', 'pricetag', 'finalizing', 'tubside', 'eadows', 'babble', 'ecosystem', 'toning', 'conduct', '22mm', 'intellisync', 'masured', 'complicated', 'lords', 'gird', 'heated', 'whose', 'sats', 'puleeeeeeeease', '78', 'gurgling', '1992', 'notebook', 'suppressing', 'imitation', 'unfillable', 'reviewer', 'barstow', '20d', 'downswing', 'pvr', 'herself', 'premiere', 'expression', 'obssessed', 'gazelle', 'palmer', 'lens', 'iolo', 'est', 'peck', 'glock', 'outrageus', 'abouve', 'gustave', 'fearlessly', 'madchild', 'decidedly', 'whimp', 'muteness', 'packet', 
#   0.84183145 -0.53218395 -0.10830293 -1.75707388  0.15026665 -0.09015331
#  -0.75104636 -0.55833817  0.11572071 -0.45007366  0.87828058 -0.30906156
#  -0.03380106  0.2906523   0.23257913 -0.78674698  0.16536587  0.69157153
#   1.0058248   0.61378413  1.44485211 -1.29121411  0.68416405 -0.05888723
#   0.08889873 -0.56972104  0.63935173  0.27509093]
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# Word2Vec(vocab=47478, size=100, alpha=0.025)

# %%
print(model['good'])
# Out:
# [-0.56806868 -1.16348171 -0.83976704  0.11632793 -0.84265792 -1.82591093
#  -1.0026288  -0.78458619 -0.77768975  0.39179593  0.96314728  0.37772095
#   0.11962517  0.0675617  -0.07766655 -0.39897838 -0.34083575 -1.20150304
#   0.86885309 -0.61695737  0.57889557  0.36058745  0.34295306 -0.12245457
#  -1.2365278   1.50321937 -2.1256218   1.06627643 -0.19291435 -0.21638124
#   0.33564389  0.63139939  0.70417118  0.13699783  1.01628602  0.12229349
#   0.91832703  0.523247   -0.10323703 -1.04559875  1.0654043  -0.34716973
#  -0.86357778  0.09413172  0.64182347 -0.08182149  1.3852483   0.79265577
#  -1.08071542 -1.95164812 -0.2302957   0.17143245 -1.40044343  0.55440736
#   0.70554453  0.66933656 -0.01515121 -0.72452581 -0.15831941  1.37229335
#  -0.96892333 -1.88286579 -0.68533099  0.55282599  0.41229942 -1.0127027
#   0.36435089 -0.54339153  0.101811    0.52002287 -0.50354391  1.371732
#   0.84183145 -0.53218395 -0.10830293 -1.75707388  0.15026665 -0.09015331
#  -0.75104636 -0.55833817  0.11572071 -0.45007366  0.87828058 -0.30906156
#  -0.03380106  0.2906523   0.23257913 -0.78674698  0.16536587  0.69157153
#   1.0058248   0.61378413  1.44485211 -1.29121411  0.68416405 -0.05888723
#   0.08889873 -0.56972104  0.63935173  0.27509093]
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#model.most_similar(positive=['good', 'best'], negative=['bad'], topn=1)
#           ability = True              pos : neg    =     10.1 : 1.0
#             waste = True              neg : pos    =     10.0 : 1.0
#             bunch = True              neg : pos    =      9.2 : 1.0
model.most_similar(positive=['good', 'best'], negative=['waste'], topn=10)
# Out:
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """
# [('discountined', 0.6664558053016663),
#  ('lyricism', 0.642421305179596),
#  ('amazing', 0.6375755071640015),
#  ('newver', 0.6288247108459473),
#  ('worst', 0.6258842945098877),
#  ('besting', 0.6250714659690857),
#  ('taglines', 0.613639771938324),
#  ('provacative', 0.6068798899650574),
#  ('clamped', 0.6023856997489929),
#  ('bisquits', 0.6001997590065002)]

# %% [markdown]
# # 1 - Cosine similarity
#
# To measure how similar two words are, we need a way to measure the degree of similarity between two embedding vectors for the two words. Given two vectors $u$ and $v$, cosine similarity is defined as follows:
#
# $$\text{CosineSimilarity(u, v)} = \frac {u . v} {||u||_2 ||v||_2} = cos(\theta) \tag{1}$$
#
# where $u.v$ is the dot product (or inner product) of two vectors, $||u||_2$ is the norm (or length) of the vector $u$, and $\theta$ is the angle between $u$ and $v$. This similarity depends on the angle between $u$ and $v$. If $u$ and $v$ are very similar, their cosine similarity will be close to 1; if they are dissimilar, the cosine similarity will take a smaller value.
#
# <img src="images/cosine_sim.png" style="width:800px;height:250px;">
# <caption><center> **Figure 1**: The cosine of the angle between two vectors is a measure of how similar they are</center></caption>
#
# **Exercise**: Implement the function `cosine_similarity()` to evaluate similarity between word vectors.
#
# **Reminder**: The norm of $u$ is defined as $ ||u||_2 = \sqrt{\sum_{i=1}^{n} u_i^2}$

# %%
# GRADED FUNCTION: cosine_similarity

def cosine_similarity(u, v):
    """
    Cosine similarity reflects the degree of similariy between u and v
        
    Arguments:
        u -- a word vector of shape (n,)          
        v -- a word vector of shape (n,)

    Returns:
        cosine_similarity -- the cosine similarity between u and v defined by the formula above.
    """
    
    distance = 0.0
    
    ### START CODE HERE ###
    # Compute the dot product between u and v (≈1 line)
    dot = np.dot(u,v)
    # Compute the L2 norm of u (≈1 line)
    norm_u = np.sqrt(sum(u**2))
    
    # Compute the L2 norm of v (≈1 line)
    norm_v = np.sqrt(sum(v**2))
    # Compute the cosine similarity defined by formula (1) (≈1 line)
    cosine_similarity = dot/(norm_u*norm_v)
    ### END CODE HERE ###
    
    return cosine_similarity

# %%
print("cosine_similarity(good, amazing) = ", cosine_similarity(model['good'],model['amazing']))
# Out:
# cosine_similarity(good, amazing) =  0.783342737439
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# PCA: a linear deterministic algorithm (principal component analysis) that tries to capture as much of the data variability in as few dimensions as possible. PCA tends to highlight large-scale structure in the data, but can distort local neighborhoods. The Embedding Projector computes the top 10 principal components, from which you can choose two or three to view.

# %%
from sklearn.decomposition import PCA
X = model[model.wv.vocab]
pca = PCA(n_components=3)
result = pca.fit_transform(X)
# Out:
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.tools.set_credentials_file(username='AlaBayoudh', api_key='oUzQzqIhUvIRYULient7')
plt.scatter(x = result[:,0],
    y = result[:,1])
'''
trace = go.Scatter(
    x = result[:,0],
    y = result[:,1],
    mode = 'markers'
)

#data = [trace]

# Plot and embed in ipython notebook!
#py.iplot(data, filename='basic-scatter')
'''
# Out:
# "\ntrace = go.Scatter(\n    x = result[:,0],\n    y = result[:,1],\n    mode = 'markers'\n)\n\n#data = [trace]\n\n# Plot and embed in ipython notebook!\n#py.iplot(data, filename='basic-scatter')\n"

# %%
f, ax = plt.subplots(figsize=(20, 12))
words = list(model.wv.vocab)
for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0], result[i, 1]))

# %%
p1 = go.Scatter3d(x = result[:,0],
    y = result[:,1],z=result[:,2],
                  mode='markers',
                  text = list(model.wv.vocab))
layout=dict(margin=dict(l=10, r=10,
                        t=30, b=10)
           )
fig = go.Figure(data=[p1], layout=layout)
# Out:
#   File "<ipython-input-33-62e3c292ec25>", line 5
#     ,color:x)
#           ^
# SyntaxError: invalid syntax

# %%
py.iplot(fig)
# Out:
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\plotly\plotly\plotly.py:224: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~AlaBayoudh/4.embed" height="525px" width="100%"></iframe>

# %%
print(pca.explained_variance_ratio_)
# Out:
# [ 0.60065532  0.07758255  0.06942301]

# %% [markdown]
# t-SNE: a nonlinear nondeterministic algorithm (T-distributed stochastic neighbor embedding) that tries to preserve local neighborhoods in the data, often at the expense of distorting global structure. You can choose whether to compute two- or three-dimensional projections.

# %%
from sklearn.manifold import TSNE
rst = TSNE(n_components=3, random_state=0).fit_transform(X[:100])

# %%
listWords = list(model.wv.vocab)

# %%
p1 = go.Scatter3d(x = rst[:,0],
    y = rst[:,1],z=rst[:,2],
                  mode='markers',
                  text = listWords[:100])
layout=dict(margin=dict(l=10, r=10,
                        t=30, b=10)
           )
fig = go.Figure(data=[p1], layout=layout)

# %%
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~AlaBayoudh/6.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Word2Vec training is an unsupervised task, there’s no good way to objectively evaluate the result. Evaluation depends on your end application.
#
# Google has released their testing set of about 20,000 syntactic and semantic test examples, following the “A is to B as C is to D” task. It is provided in the 'datasets' folder.
#
# For example a syntactic analogy of comparative type is bad:worse;good:?. There are total of 9 types of syntactic comparisons in the dataset like plural nouns and nouns of opposite meaning.
#
# The semantic questions contain five types of semantic analogies, such as capital cities (Paris:France;Tokyo:?) or family members (brother:sister;dad:?).
#
# Gensim supports the same evaluation set, in exactly the same format:

# %%
print(model.similarity('good', 'amazing'))
print(model.similarity('waste', 'bunch'))
# Out:
# 0.783342806074
# 0.625848514366
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).

# %%
print(model.predict_output_word(['good', 'waste', 'amazing']))
# Out:
# [('money', 0.65961498), ('price', 0.0084408373), ('buck', 0.0010100801), ('thing', 0.00089791534), ('very', 0.00087741629), ('quality', 0.00087091333), ('deal', 0.00070278608), ('what', 0.00064592127), ('song', 0.00064373779), ('dollar', 0.0005954295)]

# %%
def display_closestwords_tsnescatterplot(model, word):
    
    arr = np.empty((0,100), dtype='f')
    word_labels = [word]

    # get close words
    close_words = model.similar_by_word(word)
    
    # add the vector for each of the closest words to the array
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    # find tsne coords for 2 dimensions
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    # display scatter plot
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
display_closestwords_tsnescatterplot(model, 'good')
# Out:
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
#
# Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# D:\Users\ala94\Anaconda3\envs\DS\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
